# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import nrrd
print("------------------------------------------------------------------------------------------------")
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print("------------------------------------------------------------------------------------------------")
# Out:
# 2024-06-08 11:20:34.735209: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-08 11:20:35.353678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ------------------------------------------------------------------------------------------------
# 2.16.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ------------------------------------------------------------------------------------------------

# %%
def encoder_block(inputs, output_channels, lastlayer=False):
    """
    Two 3x3x3 convolutions with batch normalization and ReLU activation
    2x2x2 max pool
    """

    # 3x3x3 convolutions with ReLU activation
    x = tf.keras.layers.Conv3D(int(output_channels/2), kernel_size=3, strides=1, padding='same')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    # 2x2x2 max pool

    if not lastlayer:
        x_maxPool = tf.keras.layers.MaxPool3D(pool_size=2, strides=2, padding = 'same')(x)
    else:
        x_maxPool = x

    return x, x_maxPool

def decoder_block(inputs, skip_features, output_channels):

    # Upsampling with 2x2x2 filter
    x = tf.keras.layers.Conv3DTranspose(output_channels*2, kernel_size=2, strides=2, padding = 'same')(inputs)

# Concatenate the skip features
    x = tf.keras.layers.Concatenate()([x, skip_features])

    # 2 convolutions with 3x3 filter, batch normalization, ReLU activation
    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    return x

def unet_3D():
    inputs = tf.keras.Input(shape=(64, 64, 64, 1,))

    e1_skip, e1_maxpool = encoder_block(inputs, 64)
    e2_skip, e2_maxpool = encoder_block(e1_maxpool, 128)
    e3_skip, e3_maxpool = encoder_block(e2_maxpool, 256)
    _, e4 = encoder_block(e3_maxpool, 512, True)

    decoder1 = decoder_block(e4, e3_skip, 256)
    decoder2 = decoder_block(decoder1, e2_skip, 128)
    decoder3 = decoder_block(decoder2, e1_skip, 64)

    outputs = tf.keras.layers.Conv3D(2, 1, strides = 1)(decoder3)
    outputs = tf.keras.layers.Reshape((64*64*64, 2))(outputs)
    #outputs = tf.keras.layers.Activation('softmax')(outputs)

    model = tf.keras.models.Model(inputs = inputs,  outputs = outputs,  name = 'Unet3D')

    return model

# %%
def iou(y_true, y_pred, smooth=1):
    yt = K.argmax(y_true, axis=2)
    yp = K.argmax(y_pred, axis=2)

    intersection = K.sum(yt * yp, axis=1)
    union = K.sum(yt, axis=1) + K.sum(yp, axis=1)
    return (intersection + smooth) / (union-intersection+smooth)

# %%
model = unet_3D()
# model.summary()

print("compiling model")
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss='dice', metrics=[iou])
# Out:
# 2024-06-08 11:22:54.284722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9705 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:65:00.0, compute capability: 8.9
# compiling model

# %%
import ast
my_file = open("trainlist.txt", "r")
trainlist = my_file.read()
trainlist = ast.literal_eval(trainlist)

print("loading inputs")

number_inputs = len(trainlist)

X, _ =  nrrd.read("inputs/" + trainlist[0])
X = np.array([X]).astype(np.float32)
X = np.expand_dims(X, -1)
for i in range(1, number_inputs):

    try:
        volume, _ =  nrrd.read("inputs/" + trainlist[i])
        volume = np.array([volume])
        volume = np.expand_dims(volume, -1)
        X = np.concatenate((X, volume), axis=0)
    except:
        print("skipping " + trainlist[i])

print("loading ground truths")

valid_samples = [trainlist[0]]

y, _ =  nrrd.read("gt/" + trainlist[0])
y = np.reshape(y, (64*64*64))
y = np.array([y])
y = tf.one_hot(y, 2)
for i in range(1, number_inputs):
    try:
        volume, _ =  nrrd.read("gt/" + trainlist[i])
        volume = np.reshape(volume, (64*64*64))
        volume = np.array([volume])
        volume = tf.one_hot(volume, 2)
        y = np.concatenate((y, volume), axis=0)
        valid_samples.append(trainlist[i])
    except:
        print("skipping " + trainlist[i])

print(valid_samples)
# Out:
# loading inputs
# skipping 31_volume_10.nrrd
# skipping 63_volume_8.nrrd
# skipping 84_volume_7.nrrd
# skipping 91_volume_10.nrrd
# skipping 91_volume_9.nrrd
# loading ground truths
# skipping 31_volume_10.nrrd
# skipping 63_volume_8.nrrd
# skipping 84_volume_7.nrrd
# skipping 91_volume_10.nrrd
# skipping 91_volume_9.nrrd
# ['11_volume_1.nrrd', '11_volume_10.nrrd', '11_volume_11.nrrd', '11_volume_12.nrrd', '11_volume_2.nrrd', '11_volume_3.nrrd', '11_volume_4.nrrd', '11_volume_5.nrrd', '11_volume_6.nrrd', '11_volume_7.nrrd', '11_volume_8.nrrd', '11_volume_9.nrrd', '12_volume_1.nrrd', '12_volume_10.nrrd', '12_volume_11.nrrd', '12_volume_12.nrrd', '12_volume_13.nrrd', '12_volume_14.nrrd', '12_volume_15.nrrd', '12_volume_16.nrrd', '12_volume_17.nrrd', '12_volume_2.nrrd', '12_volume_3.nrrd', '12_volume_4.nrrd', '12_volume_5.nrrd', '12_volume_6.nrrd', '12_volume_7.nrrd', '12_volume_8.nrrd', '12_volume_9.nrrd', '13_volume_1.nrrd', '13_volume_2.nrrd', '13_volume_3.nrrd', '13_volume_4.nrrd', '13_volume_5.nrrd', '13_volume_6.nrrd', '13_volume_7.nrrd', '13_volume_8.nrrd', '14_volume_1.nrrd', '14_volume_2.nrrd', '14_volume_3.nrrd', '14_volume_4.nrrd', '14_volume_5.nrrd', '14_volume_6.nrrd', '14_volume_7.nrrd', '14_volume_8.nrrd', '14_volume_9.nrrd', '17_volume_1.nrrd', '17_volume_2.nrrd', '17_volume_3.nrrd', '17_volume_4.nrrd', '21_volume_1.nrrd', '21_volume_10.nrrd', '21_volume_11.nrrd', '21_volume_2.nrrd', '21_volume_3.nrrd', '21_volume_4.nrrd', '21_volume_5.nrrd', '21_volume_6.nrrd', '21_volume_7.nrrd', '21_volume_8.nrrd', '21_volume_9.nrrd', '25_volume_1.nrrd', '25_volume_2.nrrd', '25_volume_3.nrrd', '25_volume_4.nrrd', '25_volume_5.nrrd', '25_volume_6.nrrd', '25_volume_7.nrrd', '25_volume_8.nrrd', '25_volume_9.nrrd', '26_volume_1.nrrd', '26_volume_10.nrrd', '26_volume_11.nrrd', '26_volume_2.nrrd', '26_volume_3.nrrd', '26_volume_4.nrrd', '26_volume_5.nrrd', '26_volume_6.nrrd', '26_volume_7.nrrd', '26_volume_8.nrrd', '26_volume_9.nrrd', '29_volume_1.nrrd', '29_volume_10.nrrd', '29_volume_2.nrrd', '29_volume_3.nrrd', '29_volume_4.nrrd', '29_volume_5.nrrd', '29_volume_6.nrrd', '29_volume_7.nrrd', '29_volume_8.nrrd', '29_volume_9.nrrd', '2_volume_1.nrrd', '2_volume_2.nrrd', '2_volume_3.nrrd', '2_volume_4.nrrd', '2_volume_5.nrrd', '2_volume_6.nrrd', '2_volume_7.nrrd', '2_volume_8.nrrd', '31_volume_1.nrrd', '31_volume_2.nrrd', '31_volume_3.nrrd', '31_volume_4.nrrd', '31_volume_5.nrrd', '31_volume_6.nrrd', '31_volume_7.nrrd', '31_volume_8.nrrd', '31_volume_9.nrrd', '32_volume_1.nrrd', '32_volume_10.nrrd', '32_volume_2.nrrd', '32_volume_3.nrrd', '32_volume_4.nrrd', '32_volume_5.nrrd', '32_volume_6.nrrd', '32_volume_7.nrrd', '32_volume_8.nrrd', '32_volume_9.nrrd', '33_volume_1.nrrd', '33_volume_2.nrrd', '33_volume_3.nrrd', '33_volume_4.nrrd', '33_volume_5.nrrd', '33_volume_6.nrrd', '35_volume_1.nrrd', '35_volume_2.nrrd', '35_volume_3.nrrd', '35_volume_4.nrrd', '35_volume_5.nrrd', '35_volume_6.nrrd', '35_volume_7.nrrd', '35_volume_8.nrrd', '40_volume_1.nrrd', '40_volume_2.nrrd', '40_volume_3.nrrd', '40_volume_4.nrrd', '40_volume_5.nrrd', '45_volume_1.nrrd', '45_volume_2.nrrd', '45_volume_3.nrrd', '45_volume_4.nrrd', '45_volume_5.nrrd', '45_volume_6.nrrd', '45_volume_7.nrrd', '45_volume_8.nrrd', '46_volume_1.nrrd', '46_volume_2.nrrd', '46_volume_3.nrrd', '46_volume_4.nrrd', '46_volume_5.nrrd', '46_volume_6.nrrd', '46_volume_7.nrrd', '48_volume_1.nrrd', '48_volume_2.nrrd', '48_volume_3.nrrd', '48_volume_4.nrrd', '48_volume_5.nrrd', '48_volume_6.nrrd', '48_volume_7.nrrd', '48_volume_8.nrrd', '49_volume_1.nrrd', '49_volume_2.nrrd', '49_volume_3.nrrd', '49_volume_4.nrrd', '49_volume_5.nrrd', '52_volume_1.nrrd', '52_volume_2.nrrd', '52_volume_3.nrrd', '52_volume_4.nrrd', '52_volume_5.nrrd', '52_volume_6.nrrd', '52_volume_7.nrrd', '57_volume_1.nrrd', '57_volume_2.nrrd', '57_volume_3.nrrd', '57_volume_4.nrrd', '57_volume_5.nrrd', '57_volume_6.nrrd', '57_volume_7.nrrd', '57_volume_8.nrrd', '57_volume_9.nrrd', '5_volume_1.nrrd', '5_volume_10.nrrd', '5_volume_11.nrrd', '5_volume_12.nrrd', '5_volume_13.nrrd', '5_volume_14.nrrd', '5_volume_15.nrrd', '5_volume_16.nrrd', '5_volume_17.nrrd', '5_volume_18.nrrd', '5_volume_19.nrrd', '5_volume_2.nrrd', '5_volume_3.nrrd', '5_volume_4.nrrd', '5_volume_5.nrrd', '5_volume_6.nrrd', '5_volume_7.nrrd', '5_volume_8.nrrd', '5_volume_9.nrrd', ...

# %%
print("loading weights")

ca_mask, _ = nrrd.read("weights/" + valid_samples[0])
ca_mask = np.reshape(ca_mask, (64*64*64))
w = np.zeros((1,64*64*64,2))
for i in range(0, 64*64*64):
    if ca_mask[i] == 1:
        w[0, i] = [1,1]
for i in range(1, len(valid_samples)):
    try:
        ca_mask, _ = nrrd.read("weights/" + valid_samples[i])
        ca_mask = np.reshape(ca_mask, (64*64*64))
        w_ = np.zeros((1,64*64*64,2))
        for j in range(0, 64*64*64):
            if ca_mask[j] == 1:
                w_[0, j] = [1,1]
        w = np.concatenate((w, w_), axis=0)
    except:
        print("skipping " + valid_samples[i])
# Out:
# loading weights

# %%
# Checkpoint Saving
checkpoint_path = "./checkpoints/cp-{epoch:04d}.weights.h5"
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, verbose=1,
                                                 save_weights_only=True, save_freq=1850)


print("---------------- fitting model ---------------------")
model.fit(x=X, y=y, batch_size=2, epochs=400, sample_weight=w, callbacks = [cp_callback])
# Out:
# ---------------- fitting model ---------------------
# Epoch 1/400
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717860757.672484  679725 service.cc:145] XLA service 0x73c68400b380 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1717860757.672550  679725 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-06-08 11:32:37.856024: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-08 11:32:38.524612: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
#   1/185 ━━━━━━━━━━━━━━━━━━━━ 1:17:46 25s/step - iou: 0.0012 - loss: 0.0486
# I0000 00:00:1717860777.031975  679725 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 53s 151ms/step - iou: 0.0162 - loss: 0.0114
# Epoch 2/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1414 - loss: -0.0280
# Epoch 3/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0262 - loss: -0.0343
# Epoch 4/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0275 - loss: -0.0390
# Epoch 5/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0665 - loss: -0.0296
# Epoch 6/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6082 - loss: -0.0092
# Epoch 7/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6198 - loss: -0.0411
# Epoch 8/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6054 - loss: 0.0204
# Epoch 9/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5406 - loss: 1.0375e-04
# Epoch 10/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0178 - loss: -0.0399
# Epoch 10: saving model to ./checkpoints/cp-0010.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0176 - loss: -0.0399
# Epoch 11/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0149 - loss: -0.0125
# Epoch 12/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0420 - loss: -6.4619e-05
# Epoch 13/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.4014 - loss: -0.0151
# Epoch 14/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0837 - loss: 0.0293
# Epoch 15/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5049 - loss: 0.0023
# Epoch 16/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6254 - loss: -0.0335
# Epoch 17/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6072 - loss: 0.0165
# Epoch 18/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.3318e-04 - loss: -0.0057
# Epoch 19/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0025 - loss: -0.0292
# Epoch 20/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0189 - loss: -0.0042
# Epoch 20: saving model to ./checkpoints/cp-0020.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 155ms/step - iou: 0.0188 - loss: -0.0042
# Epoch 21/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.6497e-04 - loss: -1.3147e-04
# Epoch 22/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.9431e-04 - loss: 0.0112
# Epoch 23/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.5222e-04 - loss: 0.0013
# Epoch 24/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0231 - loss: -0.0099
# Epoch 25/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0524 - loss: -0.0212
# Epoch 26/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0526 - loss: -0.0393
# Epoch 27/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0758 - loss: -0.0426
# Epoch 28/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0269 - loss: 0.0049
# Epoch 29/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1424 - loss: 8.6413e-04
# Epoch 30/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0598 - loss: -0.0238
# Epoch 30: saving model to ./checkpoints/cp-0030.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0595 - loss: -0.0235
# Epoch 31/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.3207e-04 - loss: 0.0115
# Epoch 32/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 0.0115
# Epoch 33/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.4730e-04 - loss: 0.0105
# Epoch 34/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 8.5746e-04 - loss: 0.0105
# Epoch 35/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.6439e-04 - loss: 0.0098
# Epoch 36/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.7534e-04 - loss: 0.0096
# Epoch 37/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 7.3293e-04 - loss: 0.0097
# Epoch 38/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.3159e-04 - loss: 0.0095
# Epoch 39/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.4780e-04 - loss: 0.0090
# Epoch 40/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 8.6349e-04 - loss: 0.0079
# Epoch 40: saving model to ./checkpoints/cp-0040.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 8.6398e-04 - loss: 0.0079
# Epoch 41/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.4718e-04 - loss: 0.0078
# Epoch 42/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.6769e-04 - loss: 0.0071
# Epoch 43/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.6161e-04 - loss: 0.0068
# Epoch 44/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.4109e-04 - loss: 0.0052
# Epoch 45/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.7736e-04 - loss: 0.0049
# Epoch 46/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.5664e-04 - loss: 0.0034
# Epoch 47/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.4302e-04 - loss: 0.0026
# Epoch 48/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.1106e-04 - loss: 0.0013
# Epoch 49/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.0649e-04 - loss: -3.9465e-04
# Epoch 50/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 7.3708e-04 - loss: -0.0022
# Epoch 50: saving model to ./checkpoints/cp-0050.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 7.4007e-04 - loss: -0.0023
# Epoch 51/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: -0.0045
# Epoch 52/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0031 - loss: -0.0070
# Epoch 53/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0048 - loss: -0.0080
# Epoch 54/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0096 - loss: -0.0115
# Epoch 55/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0080 - loss: -0.0145
# Epoch 56/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0156 - loss: -0.0198
# Epoch 57/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0471 - loss: -0.0266
# Epoch 58/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1219 - loss: -0.0344
# Epoch 59/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2083 - loss: -0.0673
# Epoch 60/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0857 - loss: 0.0196
# Epoch 60: saving model to ./checkpoints/cp-0060.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0855 - loss: 0.0197
# Epoch 61/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0600 - loss: 0.0217
# Epoch 62/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0284 - loss: 0.0118
# Epoch 63/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.6871e-04 - loss: -6.3716e-04
# Epoch 64/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.9225e-04 - loss: -0.0235
# Epoch 65/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.9471e-04 - loss: -0.0212
# Epoch 66/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.9214e-04 - loss: 0.0043
# Epoch 67/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.3832e-04 - loss: -0.0067
# Epoch 68/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0168 - loss: -0.0242
# Epoch 69/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2503 - loss: 0.0145
# Epoch 70/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.2956 - loss: -0.0171
# Epoch 70: saving model to ./checkpoints/cp-0070.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.2952 - loss: -0.0170
# Epoch 71/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2037 - loss: 0.0081
# Epoch 72/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.3226 - loss: -0.0026
# Epoch 73/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1458 - loss: -0.0147
# Epoch 74/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1763 - loss: 0.0080
# Epoch 75/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5759 - loss: 0.0345
# Epoch 76/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6716 - loss: 0.0242
# Epoch 77/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.5999 - loss: 0.0142
# Epoch 78/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.4835 - loss: -0.0071
# Epoch 79/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0018 - loss: 0.0162
# Epoch 80/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 7.3644e-04 - loss: 0.0127
# Epoch 80: saving model to ./checkpoints/cp-0080.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 7.3271e-04 - loss: 0.0127
# Epoch 81/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.0486e-04 - loss: 0.0088
# Epoch 82/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.8412e-05 - loss: 0.0052
# Epoch 83/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.7743e-05 - loss: 7.8461e-04
# Epoch 84/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.5735e-05 - loss: -0.0049
# Epoch 85/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.2838e-04 - loss: -0.0178
# Epoch 86/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.1735e-04 - loss: 0.0175
# Epoch 87/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.1171e-04 - loss: 0.0086
# Epoch 88/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0452 - loss: -0.0160
# Epoch 89/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1392 - loss: 0.0194
# Epoch 90/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.1133 - loss: 0.0059
# Epoch 90: saving model to ./checkpoints/cp-0090.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.1130 - loss: 0.0059
# Epoch 91/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -0.0052
# Epoch 92/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.9999e-04 - loss: -0.0214
# Epoch 93/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0022 - loss: -0.0149
# Epoch 94/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0110 - loss: 0.0151
# Epoch 95/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0235 - loss: 0.0037
# Epoch 96/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0181 - loss: -0.0099
# Epoch 97/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0351 - loss: -0.0434
# Epoch 98/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.9502e-04 - loss: 0.0136
# Epoch 99/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.9993e-04 - loss: -0.0262
# Epoch 100/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 4.4396e-04 - loss: -0.1161
# Epoch 100: saving model to ./checkpoints/cp-0100.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 4.4628e-04 - loss: -0.1153
# Epoch 101/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 0.0179
# Epoch 102/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0114 - loss: 0.0156
# Epoch 103/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0072 - loss: 0.0131
# Epoch 104/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0029 - loss: 0.0114
# Epoch 105/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0088 - loss: 0.0086
# Epoch 106/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0117 - loss: 0.0067
# Epoch 107/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0061 - loss: 0.0039
# Epoch 108/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0188 - loss: 0.0012
# Epoch 109/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0116 - loss: -0.0013
# Epoch 110/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0228 - loss: -0.0034
# Epoch 110: saving model to ./checkpoints/cp-0110.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0229 - loss: -0.0034
# Epoch 111/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0459 - loss: -0.0052
# Epoch 112/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0620 - loss: -0.0071
# Epoch 113/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0609 - loss: -0.0095
# Epoch 114/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0986 - loss: -0.0110
# Epoch 115/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0938 - loss: -0.0194
# Epoch 116/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0891 - loss: -0.0287
# Epoch 117/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1397 - loss: -0.0546
# Epoch 118/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2242 - loss: 0.0063
# Epoch 119/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0773 - loss: 5.8957e-04
# Epoch 120/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.1469 - loss: -0.0130
# Epoch 120: saving model to ./checkpoints/cp-0120.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.1472 - loss: -0.0131
# Epoch 121/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2741 - loss: -0.0345
# Epoch 122/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0366 - loss: 0.0181
# Epoch 123/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0036 - loss: 0.0069
# Epoch 124/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.2706e-04 - loss: -0.0022
# Epoch 125/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0010 - loss: -0.0171
# Epoch 126/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0565 - loss: -0.0315
# Epoch 127/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2775 - loss: 0.0243
# Epoch 128/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5566 - loss: 0.0174
# Epoch 129/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6333 - loss: 0.0113
# Epoch 130/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.5724 - loss: 0.0036
# Epoch 130: saving model to ./checkpoints/cp-0130.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.5729 - loss: 0.0036
# Epoch 131/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6135 - loss: -0.0245
# Epoch 132/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2113 - loss: 0.0401
# Epoch 133/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2734 - loss: 0.0194
# Epoch 134/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2080 - loss: 3.1014e-04
# Epoch 135/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1129 - loss: -0.0283
# Epoch 136/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.2638 - loss: -0.0018
# Epoch 137/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.3539e-04 - loss: 0.0033
# Epoch 138/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.1892e-04 - loss: 3.6656e-04
# Epoch 139/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.2898e-04 - loss: -0.0016
# Epoch 140/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 1.7499e-04 - loss: -0.0038
# Epoch 140: saving model to ./checkpoints/cp-0140.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 1.7487e-04 - loss: -0.0038
# Epoch 141/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.4405e-04 - loss: -0.0063
# Epoch 142/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 1.9409e-04 - loss: -0.0098
# Epoch 143/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.8224e-04 - loss: -0.0139
# Epoch 144/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.2856e-04 - loss: -0.0210
# Epoch 145/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.6709e-04 - loss: -0.0319
# Epoch 146/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.4913e-04 - loss: -0.0533
# Epoch 147/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.5799e-04 - loss: -0.1526
# Epoch 148/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0247e-04 - loss: 0.0314
# Epoch 149/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.1233e-04 - loss: 0.0369
# Epoch 150/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 2.0003e-04 - loss: 0.0320
# Epoch 150: saving model to ./checkpoints/cp-0150.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 2.0011e-04 - loss: 0.0320
# Epoch 151/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0453e-04 - loss: 0.0316
# Epoch 152/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.2685e-04 - loss: 0.0285
# Epoch 153/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.5614e-04 - loss: 0.0293
# Epoch 154/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0471e-04 - loss: 0.0268
# Epoch 155/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.9537e-04 - loss: 0.0258
# Epoch 156/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.6589e-04 - loss: 0.0225
# Epoch 157/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.4337e-04 - loss: 0.0217
# Epoch 158/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.2170e-04 - loss: 0.0188
# Epoch 159/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.2408e-04 - loss: 0.0148
# Epoch 160/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 2.5947e-04 - loss: 0.0054
# Epoch 160: saving model to ./checkpoints/cp-0160.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 2.5995e-04 - loss: 0.0054
# Epoch 161/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0277 - loss: -0.0065
# Epoch 162/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1343 - loss: -0.0294
# Epoch 163/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.7061e-04 - loss: -0.1529
# Epoch 164/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0010 - loss: -0.0043
# Epoch 165/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.9019e-04 - loss: 0.0323
# Epoch 166/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.8160e-04 - loss: 0.0225
# Epoch 167/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 0.0049
# Epoch 168/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 0.0268
# Epoch 169/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0040 - loss: 0.0128
# Epoch 170/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0053 - loss: -0.0042
# Epoch 170: saving model to ./checkpoints/cp-0170.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 155ms/step - iou: 0.0053 - loss: -0.0042
# Epoch 171/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.3893e-04 - loss: -0.0144
# Epoch 172/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.7667e-04 - loss: 0.0344
# Epoch 173/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.8487e-04 - loss: -0.0047
# Epoch 174/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.7829e-04 - loss: 0.0057
# Epoch 175/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0990e-04 - loss: -0.0020
# Epoch 176/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.2618e-04 - loss: -0.0131
# Epoch 177/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.2887e-04 - loss: -0.0320
# Epoch 178/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.1883e-04 - loss: 0.0448
# Epoch 179/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.1874e-05 - loss: 0.0240
# Epoch 180/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0016 - loss: 0.8077
# Epoch 180: saving model to ./checkpoints/cp-0180.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0016 - loss: 0.8020
# Epoch 181/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: 6.3727e-04
# Epoch 182/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 7.5171e-04
# Epoch 183/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 7.4667e-04
# Epoch 184/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 6.5878e-04
# Epoch 185/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: 7.0810e-04
# Epoch 186/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: 7.3207e-04
# Epoch 187/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: 6.4627e-04
# Epoch 188/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 6.6991e-04
# Epoch 189/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: 5.6860e-04
# Epoch 190/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0016 - loss: 5.2394e-04
# Epoch 190: saving model to ./checkpoints/cp-0190.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 29s 154ms/step - iou: 0.0016 - loss: 5.2472e-04
# Epoch 191/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: 5.9543e-04
# Epoch 192/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 5.1609e-04
# Epoch 193/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.7482e-04 - loss: 5.0183e-04
# Epoch 194/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 3.7774e-04
# Epoch 195/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 4.6405e-04
# Epoch 196/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 4.1267e-04
# Epoch 197/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 4.0012e-04
# Epoch 198/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 3.8190e-04
# Epoch 199/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 1.7312e-04
# Epoch 200/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0015 - loss: 2.4592e-04
# Epoch 200: saving model to ./checkpoints/cp-0200.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.0015 - loss: 2.4567e-04
# Epoch 201/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 2.2604e-04
# Epoch 202/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 1.4640e-04
# Epoch 203/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: 1.1930e-04
# Epoch 204/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 6.5858e-05
# Epoch 205/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: -3.6087e-05
# Epoch 206/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 2.0912e-05
# Epoch 207/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -1.8396e-04
# Epoch 208/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0011 - loss: -2.6323e-04
# Epoch 209/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -3.9088e-04
# Epoch 210/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 9.9072e-04 - loss: -3.7964e-04
# Epoch 210: saving model to ./checkpoints/cp-0210.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 9.9208e-04 - loss: -3.8040e-04
# Epoch 211/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -5.2927e-04
# Epoch 212/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: -6.9242e-04
# Epoch 213/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -8.4436e-04
# Epoch 214/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: -0.0011
# Epoch 215/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: -0.0012
# Epoch 216/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: -0.0013
# Epoch 217/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0018 - loss: -0.0016
# Epoch 218/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0021 - loss: -0.0018
# Epoch 219/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0028 - loss: -0.0021
# Epoch 220/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0033 - loss: -0.0022
# Epoch 220: saving model to ./checkpoints/cp-0220.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.0033 - loss: -0.0022
# Epoch 221/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0028 - loss: -0.0025
# Epoch 222/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0034 - loss: -0.0028
# Epoch 223/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0040 - loss: -0.0029
# Epoch 224/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0032 - loss: -0.0031
# Epoch 225/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0047 - loss: -0.0034
# Epoch 226/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0033 - loss: -0.0038
# Epoch 227/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0025 - loss: -0.0037
# Epoch 228/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0023 - loss: -0.0040
# Epoch 229/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0017 - loss: -0.0040
# Epoch 230/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0020 - loss: -0.0044
# Epoch 230: saving model to ./checkpoints/cp-0230.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.0020 - loss: -0.0044
# Epoch 231/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0019 - loss: -0.0052
# Epoch 232/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: -0.0055
# Epoch 233/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: -0.0056
# Epoch 234/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -0.0064
# Epoch 235/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0015 - loss: -0.0062
# Epoch 236/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -0.0076
# Epoch 237/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: -0.0077
# Epoch 238/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.1019e-04 - loss: -0.0086
# Epoch 239/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -0.0087
# Epoch 240/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 8.7231e-04 - loss: -0.0097
# Epoch 240: saving model to ./checkpoints/cp-0240.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 8.7097e-04 - loss: -0.0097
# Epoch 241/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.0928e-04 - loss: -0.0105
# Epoch 242/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.0120e-04 - loss: -0.0122
# Epoch 243/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.9516e-04 - loss: -0.0139
# Epoch 244/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.8389e-04 - loss: -0.0167
# Epoch 245/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.7267e-04 - loss: -0.0212
# Epoch 246/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.6988e-04 - loss: -0.0322
# Epoch 247/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.4419e-04 - loss: -0.0469
# Epoch 248/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.7997e-04 - loss: -0.1170
# Epoch 249/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.9161e-05 - loss: 0.0391
# Epoch 250/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 4.9165e-05 - loss: 0.0397
# Epoch 250: saving model to ./checkpoints/cp-0250.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 4.9405e-05 - loss: 0.0397
# Epoch 251/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.5747e-05 - loss: 0.0387
# Epoch 252/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.4424e-05 - loss: 0.0362
# Epoch 253/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.6926e-05 - loss: 0.0354
# Epoch 254/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.9126e-05 - loss: 0.0314
# Epoch 255/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.8361e-05 - loss: 0.0323
# Epoch 256/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.2522e-05 - loss: 0.0293
# Epoch 257/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.5787e-05 - loss: 0.0267
# Epoch 258/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 6.0913e-05 - loss: 0.0253
# Epoch 259/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 8.6749e-05 - loss: 0.0225
# Epoch 260/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - iou: 1.1249e-04 - loss: 0.0185
# Epoch 260: saving model to ./checkpoints/cp-0260.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 1.1241e-04 - loss: 0.0185
# Epoch 261/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.3409e-04 - loss: 0.0160
# Epoch 262/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0650e-04 - loss: 0.0117
# Epoch 263/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.6876e-04 - loss: 0.0072
# Epoch 264/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 5.3535e-04 - loss: 0.0016
# Epoch 265/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.5767e-04 - loss: -0.0053
# Epoch 266/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0051 - loss: -0.0175
# Epoch 267/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1054 - loss: -0.0489
# Epoch 268/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0052 - loss: 0.0124
# Epoch 269/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0041 - loss: 0.0113
# Epoch 270/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0028 - loss: 0.0086
# Epoch 270: saving model to ./checkpoints/cp-0270.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.0028 - loss: 0.0086
# Epoch 271/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0017 - loss: 0.0071
# Epoch 272/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0082 - loss: 0.0046
# Epoch 273/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0044 - loss: 0.0020
# Epoch 274/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.2696e-04 - loss: -0.0015
# Epoch 275/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0102 - loss: -0.0121
# Epoch 276/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.6931e-04 - loss: -0.0355
# Epoch 277/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0034 - loss: 0.0312
# Epoch 278/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0174 - loss: 0.0334
# Epoch 279/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0142 - loss: 0.0295
# Epoch 280/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0145 - loss: 0.0288
# Epoch 280: saving model to ./checkpoints/cp-0280.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.0145 - loss: 0.0287
# Epoch 281/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0030 - loss: 0.0259
# Epoch 282/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0205 - loss: 0.0219
# Epoch 283/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0085 - loss: 0.0220
# Epoch 284/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0153 - loss: 0.0194
# Epoch 285/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0094 - loss: 0.0169
# Epoch 286/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1026 - loss: 0.0142
# Epoch 287/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.3802 - loss: 0.0096
# Epoch 288/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.4125 - loss: 0.0020
# Epoch 289/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.4556 - loss: -0.0210
# Epoch 290/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 8.8869e-04 - loss: 0.0154
# Epoch 290: saving model to ./checkpoints/cp-0290.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 8.8786e-04 - loss: 0.0154
# Epoch 291/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: 0.0105
# Epoch 292/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.0577e-04 - loss: 0.0074
# Epoch 293/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.3079e-04 - loss: 0.0020
# Epoch 294/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.1019e-04 - loss: -0.0042
# Epoch 295/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.8726e-04 - loss: -0.0191
# Epoch 296/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.0568e-04 - loss: -0.1122
# Epoch 297/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.6350e-04 - loss: 0.0204
# Epoch 298/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.7512e-04 - loss: 0.0188
# Epoch 299/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0020 - loss: 0.0154
# Epoch 300/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0013 - loss: 0.0148
# Epoch 300: saving model to ./checkpoints/cp-0300.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.0013 - loss: 0.0148
# Epoch 301/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0017 - loss: 0.0128
# Epoch 302/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0020 - loss: 0.0115
# Epoch 303/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0022 - loss: 0.0093
# Epoch 304/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0019 - loss: 0.0063
# Epoch 305/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0022 - loss: 0.0028
# Epoch 306/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0016 - loss: -0.0031
# Epoch 307/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0011 - loss: -0.0153
# Epoch 308/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0821 - loss: -0.0396
# Epoch 309/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5139 - loss: 0.0185
# Epoch 310/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.3034 - loss: 0.0147
# Epoch 310: saving model to ./checkpoints/cp-0310.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.3024 - loss: 0.0147
# Epoch 311/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 6.1767e-04 - loss: 0.0092
# Epoch 312/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.2332e-05 - loss: -5.9678e-04
# Epoch 313/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 1.4562e-04 - loss: -0.0285
# Epoch 314/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.1202e-04 - loss: 0.0293
# Epoch 315/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.0327e-04 - loss: 0.0303
# Epoch 316/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.6511e-04 - loss: 0.0262
# Epoch 317/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.4535e-04 - loss: 0.0207
# Epoch 318/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.4525e-04 - loss: 0.0173
# Epoch 319/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.9138e-04 - loss: 0.0132
# Epoch 320/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 3.1618e-04 - loss: 0.0079
# Epoch 320: saving model to ./checkpoints/cp-0320.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 3.1682e-04 - loss: 0.0079
# Epoch 321/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.2517e-04 - loss: 0.0030
# Epoch 322/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.3299e-04 - loss: -0.0051
# Epoch 323/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.1631e-04 - loss: -0.0241
# Epoch 324/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.6321e-04 - loss: 0.0048
# Epoch 325/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0042 - loss: 0.0159
# Epoch 326/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0043 - loss: 0.0011
# Epoch 327/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5748 - loss: 0.0325
# Epoch 328/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0188 - loss: 0.0169
# Epoch 329/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.1048e-04 - loss: -0.0082
# Epoch 330/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 2.5059e-04 - loss: 0.0179
# Epoch 330: saving model to ./checkpoints/cp-0330.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 2.5056e-04 - loss: 0.0178
# Epoch 331/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.8107e-04 - loss: 0.0126
# Epoch 332/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.9673e-04 - loss: 0.0083
# Epoch 333/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 2.6571e-04 - loss: 0.0020
# Epoch 334/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.1317e-04 - loss: -0.0018
# Epoch 335/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.5679e-04 - loss: -0.0077
# Epoch 336/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 4.8221e-04 - loss: -0.0171
# Epoch 337/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0197 - loss: -0.0292
# Epoch 338/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5783 - loss: -0.0578
# Epoch 339/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6537 - loss: 0.0394
# Epoch 340/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.6211 - loss: 0.0388
# Epoch 340: saving model to ./checkpoints/cp-0340.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.6211 - loss: 0.0388
# Epoch 341/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6227 - loss: 0.0356
# Epoch 342/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5875 - loss: 0.0298
# Epoch 343/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.4724 - loss: 0.0294
# Epoch 344/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.5872e-04 - loss: 0.0195
# Epoch 345/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.7384e-04 - loss: 0.0062
# Epoch 346/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 1.0171e-04 - loss: -0.0059
# Epoch 347/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.2498e-05 - loss: 0.0218
# Epoch 348/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.1156e-05 - loss: 0.0099
# Epoch 349/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.2969e-05 - loss: -0.0020
# Epoch 350/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 5.6563e-05 - loss: -0.0153
# Epoch 350: saving model to ./checkpoints/cp-0350.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 5.6586e-05 - loss: -0.0153
# Epoch 351/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.7853e-05 - loss: -0.0027
# Epoch 352/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.3334e-04 - loss: 0.0193
# Epoch 353/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.9040e-04 - loss: 0.0169
# Epoch 354/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.4240e-04 - loss: 0.0158
# Epoch 355/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 5.6013e-04 - loss: 0.0134
# Epoch 356/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.1519e-04 - loss: 0.0131
# Epoch 357/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.7036e-04 - loss: 0.0138
# Epoch 358/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: 0.0112
# Epoch 359/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 0.0109
# Epoch 360/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0010 - loss: 0.0104
# Epoch 360: saving model to ./checkpoints/cp-0360.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.0010 - loss: 0.0104
# Epoch 361/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0013 - loss: 0.0084
# Epoch 362/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.7365e-04 - loss: 0.0068
# Epoch 363/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.4705e-04 - loss: 0.0038
# Epoch 364/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.5371e-04 - loss: -0.0057
# Epoch 365/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.1227e-04 - loss: -0.0262
# Epoch 366/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.4643e-04 - loss: 0.0062
# Epoch 367/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.0162e-04 - loss: 0.0270
# Epoch 368/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.5550e-04 - loss: 0.0206
# Epoch 369/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.3615e-04 - loss: 0.0156
# Epoch 370/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 5.0571e-04 - loss: 0.0100
# Epoch 370: saving model to ./checkpoints/cp-0370.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 5.0733e-04 - loss: 0.0100
# Epoch 371/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.6752e-04 - loss: 0.0025
# Epoch 372/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.4016e-04 - loss: -0.0050
# Epoch 373/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 4.3575e-04 - loss: -0.0146
# Epoch 374/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.2003e-04 - loss: -0.0327
# Epoch 375/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0621 - loss: -0.0452
# Epoch 376/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0561 - loss: 0.0469
# Epoch 377/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 9.6426e-04 - loss: 0.0323
# Epoch 378/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 2.6084e-04 - loss: 0.0049
# Epoch 379/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.1817 - loss: 0.0053
# Epoch 380/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.5224 - loss: 0.0304
# Epoch 380: saving model to ./checkpoints/cp-0380.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.5232 - loss: 0.0304
# Epoch 381/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.6635 - loss: 0.0200
# Epoch 382/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.5808 - loss: 0.0094
# Epoch 383/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0012 - loss: -0.0164
# Epoch 384/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 3.8749e-04 - loss: 0.0174
# Epoch 385/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 7.4362e-04 - loss: 0.0162
# Epoch 386/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 8.4433e-04 - loss: 0.0147
# Epoch 387/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 151ms/step - iou: 0.0016 - loss: 0.0158
# Epoch 388/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0070 - loss: 0.0145
# Epoch 389/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0075 - loss: 0.0130
# Epoch 390/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0012 - loss: 0.0121
# Epoch 390: saving model to ./checkpoints/cp-0390.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 153ms/step - iou: 0.0012 - loss: 0.0121
# Epoch 391/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0069 - loss: 0.0118
# Epoch 392/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0036 - loss: 0.0107
# Epoch 393/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0108 - loss: 0.0101
# Epoch 394/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0089 - loss: 0.0103
# Epoch 395/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0030 - loss: 0.0099
# Epoch 396/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0014 - loss: 0.0087
# Epoch 397/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0033 - loss: 0.0087
# Epoch 398/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0142 - loss: 0.0070
# Epoch 399/400
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 152ms/step - iou: 0.0264 - loss: 0.0057
# Epoch 400/400
# 184/185 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - iou: 0.0120 - loss: 0.0056
# Epoch 400: saving model to ./checkpoints/cp-0400.weights.h5
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 28s 154ms/step - iou: 0.0120 - loss: 0.0056
