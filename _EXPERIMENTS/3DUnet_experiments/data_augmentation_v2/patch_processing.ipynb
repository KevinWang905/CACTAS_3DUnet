# %%
# %pip install opencv-python
# Out:
# /bin/bash: /home/kevin.wang/miniconda3/envs/tf-gpu-py310/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.82-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.10.0.82-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 133.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.82
# Note: you may need to restart the kernel to use updated packages.

# %%
import nrrd
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
import random

# %%
trainlist = [2, 5, 6, 7, 9, 11, 12, 13, 14, 17, 21, 25, 26, 29, 31, 32, 33, 35, 40, 45, 46, 48, 49, 52, 57, 60, 61, 63, 64, 69, 72, 75, 79, 83, 84, 87, 88, 91, 92, 95, 96, 97]

# %%
len(trainlist)
# Out:
# 42

# %%
def random_warp(img, plane):
    (h, w) = img.shape[:2]
    (cX, cY) = (w // 2, h // 2)
    if plane == 'xy':
        theta = random.randint(0, 360)
    else:
        theta = 0
    rotation = cv2.getRotationMatrix2D((cX, cY), theta, 1.0)

    if plane == 'xy': 
        scale_x = np.round(random.uniform(0.75, 1.25), 2)
        scale_y = np.round(random.uniform(0.75, 1.25), 2)
    else:
        scale_x = 1
        scale_y = 1
    scale = np.array([[scale_x, 0, 0],
                    [0, scale_y, 0],
                    [0, 0, 1]])
    scale[0,2] = -((scale[0,0] * w/2) - w/2 )
    scale[1,2] = -((scale[1,1] * h/2) - h/2 )

    
    if plane == 'xy':
        shear_x = np.round(random.uniform(-0.25, 0.25), 2)
        shear_y = np.round(random.uniform(-0.25, 0.25), 2)
    else:
        shear_x = np.round(random.uniform(-0.15, 0.15), 2)
        shear_y = np.round(random.uniform(-0.15, 0.15), 2)

    shear = np.array([[1, shear_x, 0],
                    [shear_y, 1, 0],
                    [0, 0, 1]])
    shear[0,2] = -shear[0,1] * w/2
    shear[1,2] = -shear[1,0] * h/2

    affine = np.matmul(np.matmul(rotation, scale), shear)
    return affine[:2]

# %%
for number in trainlist:

    for augmentation in range(0, 3):
        print(number, augmentation)
        ca, _ = nrrd.read("../../CA/"+str(number)+".ca.seg.nrrd")
        dilation_size = 3
        element = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2 * dilation_size + 1, 2 * dilation_size + 1), (dilation_size, dilation_size))
        for i in range(0, ca.shape[2]):
            ca[:,:,i] = cv2.dilate(ca[:,:,i], element)
        ca_copy = ca.copy()
        full_ct, _ =  nrrd.read("../../ESUS/"+str(number)+".img.nrrd")
        masked = ca * full_ct
        masked = (masked-np.min(masked)) / (np.max(masked)-np.min(masked))
        gt, _ =  nrrd.read("../../ESUS/"+str(number)+".b.seg.nrrd")
        gt[gt>1] = 1 # make all plaque segments 1 instead of a new number for each one
        
        if augmentation > 0:
        # skip augmentation if theres no plaque in patch
            if np.sum(gt) == 0:
                continue

        if augmentation > 0:
                
            # warp on x y plane
            xy_transform = random_warp(gt[:,:,0], 'xy')
            w, h = gt[:,:,0].shape[1], gt[:,:,0].shape[0]
            
            for i in range(0, gt.shape[2]):
                gt[:,:,i] = cv2.warpAffine(gt[:,:,i], xy_transform, (w, h))
                masked[:,:,i] = cv2.warpAffine(masked[:,:,i], xy_transform, (w, h))
                ca[:,:,i] = cv2.warpAffine(ca[:,:,i], xy_transform, (w, h))
            
            # warp on x z plane
            xz_transform = random_warp(gt[:,0,:], 'xz')
            w, h = gt[:,0,:].shape[1], gt[:,0,:].shape[0]
            
            for i in range(0, gt.shape[1]):
                gt[:,i,:] = cv2.warpAffine(gt[:,i,:], xz_transform, (w, h))
                masked[:,i,:] = cv2.warpAffine(masked[:,i,:], xz_transform, (w, h))
                ca[:,i,:] = cv2.warpAffine(ca[:,i,:], xz_transform, (w, h))
        
    
        current_volume = 1
        for i in range(0, ca.shape[2]):
            if np.sum(ca[:,:,i]) > 0:
                
                contours, _ = cv2.findContours(ca[:,:,i], mode=cv2.RETR_EXTERNAL, method=cv2.CHAIN_APPROX_SIMPLE)
                for c in contours:
                    try:
                        # compute the center of the contour
                        M = cv2.moments(c)
                        cX = int(M["m10"] / M["m00"])
                        cY = int(M["m01"] / M["m00"])
                        
                        volume = masked[int(cY-32):int(cY+32), int(cX-32):int(cX+32), i:i+64]
                        nrrd.write("./inputs/"+str(number)+"_volume_"+str(current_volume)+"_aug_"+str(augmentation)+".nrrd", volume)
    
                        volume_gt = gt[int(cY-32):int(cY+32), int(cX-32):int(cX+32), i:i+64]
                        nrrd.write("./gt/"+str(number)+"_volume_"+str(current_volume)+"_aug_"+str(augmentation)+".nrrd", volume_gt)
    
                        ca[int(cY-32):int(cY+32), int(cX-32):int(cX+32), i:i+64] = 0
                        current_volume += 1
                    except:
                        pass
# Out:
# 2 0
# 2 1
# 2 2
# 5 0
# 5 1
# 5 2
# 6 0
# 6 1
# 6 2
# 7 0
# 7 1
# 7 2
# 9 0
# 9 1
# 9 2
# 11 0
# 11 1
# 11 2
# 12 0
# 12 1
# 12 2
# 13 0
# 13 1
# 13 2
# 14 0
# 14 1
# 14 2
# 17 0
# 17 1
# 17 2
# 21 0
# 21 1
# 21 2
# 25 0
# 25 1
# 25 2
# 26 0
# 26 1
# 26 2
# 29 0
# 29 1
# 29 2
# 31 0
# 31 1
# 31 2
# 32 0
# 32 1
# 32 2
# 33 0
# 33 1
# 33 2
# 35 0
# 35 1
# 35 2
# 40 0
# 40 1
# 40 2
# 45 0
# 45 1
# 45 2
# 46 0
# 46 1
# 46 2
# 48 0
# 48 1
# 48 2
# 49 0
# 49 1
# 49 2
# 52 0
# 52 1
# 52 2
# 57 0
# 57 1
# 57 2
# 60 0
# 60 1
# 60 2
# 61 0
# 61 1
# 61 2
# 63 0
# 63 1
# 63 2
# 64 0
# 64 1
# 64 2
# 69 0
# 69 1
# 69 2
# 72 0
# 72 1
# 72 2
# 75 0
# 75 1
# 75 2
# 79 0
# 79 1
# 79 2
# 83 0
# 83 1
# 83 2
# 84 0
# 84 1
# 84 2
# 87 0
# 87 1
# 87 2
# 88 0
# 88 1
# 88 2
# 91 0
# 91 1
# 91 2
# 92 0
# 92 1
# 92 2
# 95 0
# 95 1
# 95 2
# 96 0
# 96 1
# 96 2
# 97 0
# 97 1
# 97 2

# %%
trainlist = os.listdir("./gt")

# %%
trainlist
# Out:
# ['21_volume_10_aug_0.nrrd',
#  '12_volume_10_aug_0.nrrd',
#  '63_volume_13_aug_1.nrrd',
#  '9_volume_6_aug_2.nrrd',
#  '21_volume_8_aug_0.nrrd',
#  '49_volume_8_aug_2.nrrd',
#  '75_volume_1_aug_1.nrrd',
#  '7_volume_17_aug_2.nrrd',
#  '60_volume_5_aug_2.nrrd',
#  '48_volume_7_aug_0.nrrd',
#  '48_volume_1_aug_1.nrrd',
#  '61_volume_1_aug_1.nrrd',
#  '61_volume_1_aug_2.nrrd',
#  '83_volume_4_aug_0.nrrd',
#  '75_volume_4_aug_0.nrrd',
#  '45_volume_4_aug_1.nrrd',
#  '95_volume_3_aug_1.nrrd',
#  '7_volume_13_aug_0.nrrd',
#  '60_volume_13_aug_2.nrrd',
#  '25_volume_4_aug_1.nrrd',
#  '7_volume_12_aug_2.nrrd',
#  '25_volume_8_aug_2.nrrd',
#  '61_volume_2_aug_1.nrrd',
#  '45_volume_4_aug_0.nrrd',
#  '75_volume_7_aug_1.nrrd',
#  '25_volume_3_aug_0.nrrd',
#  '95_volume_9_aug_1.nrrd',
#  '40_volume_7_aug_1.nrrd',
#  '63_volume_6_aug_0.nrrd',
#  '7_volume_8_aug_0.nrrd',
#  '88_volume_5_aug_1.nrrd',
#  '83_volume_2_aug_2.nrrd',
#  '5_volume_5_aug_2.nrrd',
#  '72_volume_8_aug_0.nrrd',
#  '33_volume_7_aug_2.nrrd',
#  '87_volume_3_aug_2.nrrd',
#  '83_volume_1_aug_1.nrrd',
#  '2_volume_2_aug_1.nrrd',
#  '5_volume_15_aug_0.nrrd',
#  '97_volume_4_aug_0.nrrd',
#  '97_volume_4_aug_2.nrrd',
#  '25_volume_2_aug_1.nrrd',
#  '5_volume_22_aug_1.nrrd',
#  '5_volume_14_aug_1.nrrd',
#  '7_volume_11_aug_0.nrrd',
#  '32_volume_7_aug_2.nrrd',
#  '48_volume_7_aug_1.nrrd',
#  '96_volume_5_aug_2.nrrd',
#  '11_volume_5_aug_1.nrrd',
#  '25_volume_5_aug_0.nrrd',
#  '9_volume_5_aug_2.nrrd',
#  '5_volume_15_aug_2.nrrd',
#  '60_volume_15_aug_0.nrrd',
#  '95_volume_7_aug_1.nrrd',
#  '26_volume_12_aug_1.nrrd',
#  '75_volume_5_aug_0.nrrd',
#  '72_volume_5_aug_0.nrrd',
#  '32_volume_8_aug_2.nrrd',
#  '96_volume_1_aug_2.nrrd',
#  '92_volume_6_aug_2.nrrd',
#  '87_volume_1_aug_1.nrrd',
#  '35_volume_8_aug_2.nrrd',
#  '75_volume_3_aug_1.nrrd',
#  '13_volume_11_aug_2.nrrd',
#  '61_volume_8_aug_2.nrrd',
#  '5_volume_2_aug_1.nrrd',
#  '33_volume_1_aug_2.nrrd',
#  '57_volume_3_aug_1.nrrd',
#  '17_volume_1_aug_0.nrrd',
#  '14_volume_5_aug_1.nrrd',
#  '97_volume_1_aug_2.nrrd',
#  '11_volume_4_aug_2.nrrd',
#  '29_volume_6_aug_0.nrrd',
#  '9_volume_8_aug_0.nrrd',
#  '72_volume_1_aug_2.nrrd',
#  '32_volume_1_aug_1.nrrd',
#  '46_volume_6_aug_0.nrrd',
#  '97_volume_8_aug_1.nrrd',
#  '13_volume_4_aug_1.nrrd',
#  '6_volume_4_aug_2.nrrd',
#  '7_volume_2_aug_1.nrrd',
#  '26_volume_10_aug_2.nrrd',
#  '64_volume_9_aug_0.nrrd',
#  '84_volume_1_aug_1.nrrd',
#  '40_volume_5_aug_2.nrrd',
#  '72_volume_1_aug_1.nrrd',
#  '69_volume_5_aug_1.nrrd',
#  '31_volume_3_aug_1.nrrd',
#  '6_volume_3_aug_0.nrrd',
#  '40_volume_4_aug_2.nrrd',
#  '14_volume_8_aug_1.nrrd',
#  '5_volume_1_aug_1.nrrd',
#  '35_volume_8_aug_0.nrrd',
#  '12_volume_1_aug_1.nrrd',
#  '31_volume_8_aug_1.nrrd',
#  '72_volume_1_aug_0.nrrd',
#  '26_volume_8_aug_1.nrrd',
#  '35_volume_2_aug_0.nrrd',
#  '57_volume_4_aug_2.nrrd',
#  '9_volume_5_aug_1.nrrd',
#  '84_volume_1_aug_0.nrrd',
#  '49_volume_3_aug_0.nrrd',
#  '92_volume_1_aug_2.nrrd',
#  '87_volume_8_aug_1.nrrd',
#  '48_volume_3_aug_1.nrrd',
#  '6_volume_9_aug_2.nrrd',
#  '87_volume_7_aug_1.nrrd',
#  '84_volume_5_aug_0.nrrd',
#  '48_volume_3_aug_0.nrrd',
#  '26_volume_6_aug_0.nrrd',
#  '87_volume_9_aug_1.nrrd',
#  '14_volume_8_aug_0.nrrd',
#  '46_volume_3_aug_0.nrrd',
#  '31_volume_6_aug_1.nrrd',
#  '13_volume_6_aug_0.nrrd',
#  '5_volume_5_aug_1.nrrd',
#  '96_volume_4_aug_0.nrrd',
#  '57_volume_3_aug_0.nrrd',
#  '21_volume_1_aug_1.nrrd',
#  '14_volume_14_aug_2.nrrd',
#  '95_volume_8_aug_0.nrrd',
#  '46_volume_4_aug_2.nrrd',
#  '12_volume_5_aug_2.nrrd',
#  '7_volume_8_aug_2.nrrd',
#  '12_volume_8_aug_2.nrrd',
#  '12_volume_19_aug_2.nrrd',
#  '5_volume_7_aug_0.nrrd',
#  '72_volume_4_aug_1.nrrd',
#  '45_volume_8_aug_0.nrrd',
#  '32_volume_10_aug_2.nrrd',
#  '52_volume_2_aug_0.nrrd',
#  '46_volume_7_aug_1.nrrd',
#  '2_volume_2_aug_2.nrrd',
#  '21_volume_5_aug_2.nrrd',
#  '52_volume_3_aug_0.nrrd',
#  '57_volume_6_aug_1.nrrd',
#  '79_volume_4_aug_2.nrrd',
#  '91_volume_10_aug_0.nrrd',
#  '31_volume_4_aug_2.nrrd',
#  '96_volume_7_aug_0.nrrd',
#  '12_volume_10_aug_1.nrrd',
#  '84_volume_3_aug_0.nrrd',
#  '29_volume_3_aug_0.nrrd',
#  '6_volume_1_aug_2.nrrd',
#  '48_volume_6_aug_1.nrrd',
#  '60_volume_10_aug_0.nrrd',
#  '64_volume_1_aug_2.nrrd',
#  '14_volume_3_aug_1.nrrd',
#  '61_volume_4_aug_1.nrrd',
#  '35_volume_2_aug_2.nrrd',
#  '60_volume_9_aug_1.nrrd',
#  '79_volume_1_aug_0.nrrd',
#  '60_volume_12_aug_0.nrrd',
#  '13_volume_5_aug_1.nrrd',
#  '2_volume_1_aug_1.nrrd',
#  '45_volume_1_aug_1.nrrd',
#  '7_volume_4_aug_2.nrrd',
#  '25_volume_12_aug_2.nrrd',
#  '7_volume_15_aug_2.nrrd',
#  '12_volume_4_aug_2.nrrd',
#  '14_volume_2_aug_0.nrrd',
#  '14_volume_1_aug_2.nrrd',
#  '63_volume_1_aug_1.nrrd',
#  '79_volume_2_aug_0.nrrd',
#  '69_volume_3_aug_1.nrrd',
#  '13_volume_8_aug_1.nrrd',
#  '97_volume_2_aug_0.nrrd',
#  '92_volume_4_aug_1.nrrd',
#  '75_volume_5_aug_1.nrrd',
#  '40_volume_2_aug_2.nrrd',
#  '46_volume_7_aug_2.nrrd',
#  '11_volume_10_aug_2.nrrd',
#  '72_volume_4_aug_2.nrrd',
#  '61_volume_3_aug_1.nrrd',
#  '2_volume_5_aug_2.nrrd',
#  '26_volume_13_aug_1.nrrd',
#  '87_volume_2_aug_0.nrrd',
#  '26_volume_11_aug_0.nrrd',
#  '35_volume_10_aug_1.nrrd',
#  '6_volume_2_aug_1.nrrd',
#  '5_volume_19_aug_2.nrrd',
#  '83_volume_6_aug_0.nrrd',
#  '21_volume_1_aug_2.nrrd',
#  '84_volume_2_aug_1.nrrd',
#  '57_volume_6_aug_2.nrrd',
#  '21_volume_2_aug_2.nrrd',
#  '60_volume_5_aug_1.nrrd',
#  '72_volume_3_aug_2.nrrd',
#  '91_volume_3_aug_0.nrrd',
#  '64_volume_8_aug_2.nrrd',
#  '57_volume_7_aug_2.nrrd',
#  '7_volume_6_aug_2.nrrd',
#  '11_volume_10_aug_0.nrrd',
#  '48_volume_1_aug_0.nrrd',
#  '31_volume_3_aug_2.nrrd',
#  '91_volume_4_aug_1.nrrd',
#  '45_volume_2_aug_1.nrrd',
#  '7_volume_20_aug_2.nrrd',
#  '57_volume_8_aug_0.nrrd',
#  '31_volume_8_aug_2.nrrd',
#  '45_volume_1_aug_2.nrrd',
#  '29_volume_4_aug_2.nrrd',
#  '11_volume_16_aug_1.nrrd',
#  '95_volume_6_aug_0.nrrd',
#  '40_volume_5_aug_0.nrrd',
#  '31_volume_4_aug_1.nrrd',
#  '63_volume_8_aug_1.nrrd',
#  '29_volume_10_aug_1.nrrd',
#  '48_volume_9_aug_2.nrrd',
#  '7_volume_1_aug_1.nrrd',
#  '49_volume_2_aug_2.nrrd',
#  '35_volume_3_aug_0.nrrd',
#  '52_volume_1_aug_1.nrrd',
#  '25_volume_9_aug_2.nrrd',
#  '75_volume_9_aug_2.nrrd',
#  '12_volume_2_aug_0.nrrd',
#  '29_volume_6_aug_1.nrrd',
#  '91_volume_2_aug_2.nrrd',
#  '14_volume_3_aug_0.nrrd',
#  '14_volume_3_aug_2.nrrd',
#  '25_volume_8_aug_0.nrrd',
#  '92_volume_1_aug_1.nrrd',
#  '11_volume_8_aug_1.nrrd',
#  '13_volume_10_aug_2.nrrd',
#  '52_volume_7_aug_0.nrrd',
#  '31_volume_9_aug_1.nrrd',
#  '83_volume_2_aug_1.nrrd',
#  '87_volume_6_aug_2.nrrd',
#  '92_volume_5_aug_0.nrrd',
#  '26_volume_9_aug_2.nrrd',
#  '61_volume_9_aug_1.nrrd',
#  '5_volume_6_aug_1.nrrd',
#  '45_volume_2_aug_2.nrrd',
#  '11_volume_9_aug_1.nrrd',
#  '13_volume_7_aug_0.nrrd',
#  '40_volume_1_aug_1.nrrd',
#  '87_volume_8_aug_0.nrrd',
#  '5_volume_14_aug_0.nrrd',
#  '31_volume_10_aug_1.nrrd',
#  '96_volume_2_aug_1.nrrd',
#  '61_volume_6_aug_0.nrrd',
#  '63_volume_9_aug_1.nrrd',
#  '32_volume_2_aug_2.nrrd',
#  '7_volume_10_aug_2.nrrd',
#  '87_volume_5_aug_1.nrrd',
#  '64_volume_3_aug_2.nrrd',
#  '33_volume_2_aug_0.nrrd',
#  '26_volume_10_aug_1.nrrd',
#  '48_volume_2_aug_0.nrrd',
#  '97_volume_7_aug_1.nrrd',
#  '2_volume_1_aug_0.nrrd',
#  '72_volume_6_aug_0.nrrd',
#  '87_volume_9_aug_0.nrrd',
#  '12_volume_16_aug_0.nrrd',
#  '52_volume_4_aug_1.nrrd',
#  '96_volume_7_aug_1.nrrd',
#  '96_volume_6_aug_0.nrrd',
#  '21_volume_3_aug_0.nrrd',
#  '84_volume_7_aug_0.nrrd',
#  '14_volume_6_aug_0.nrrd',
#  '95_volume_1_aug_1.nrrd',
#  '31_volume_1_aug_0.nrrd',
#  '21_volume_7_aug_1.nrrd',
#  '92_volume_3_aug_1.nrrd',
#  '5_volume_19_aug_0.nrrd',
#  '17_volume_3_aug_2.nrrd',
#  '75_volume_3_aug_0.nrrd',
#  '12_volume_7_aug_2.nrrd',
#  '25_volume_3_aug_2.nrrd',
#  '49_volume_5_aug_1.nrrd',
#  '35_volume_1_aug_2.nrrd',
#  '45_volume_7_aug_2.nrrd',
#  '72_volume_8_aug_2.nrrd',
#  '11_volume_7_aug_1.nrrd',
#  '13_volume_4_aug_0.nrrd',
#  '88_volume_3_aug_2.nrrd',
#  '72_volume_7_aug_1.nrrd',
#  '92_volume_3_aug_0.nrrd',
#  '12_volume_13_aug_1.nrrd',
#  '96_volume_4_aug_1.nrrd',
#  '12_volume_11_aug_2.nrrd',
#  '92_volume_8_aug_1.nrrd',
#  '25_volume_5_aug_2.nrrd',
#  '60_volume_3_aug_1.nrrd',
#  '31_volume_11_aug_1.nrrd',
#  '17_volume_4_aug_1.nrrd',
#  '91_volume_5_aug_1.nrrd',
#  '29_volume_3_aug_2.nrrd',
#  '49_volume_4_aug_1.nrrd',
#  '64_volume_1_aug_0.nrrd',
#  '5_volume_11_aug_0.nrrd',
#  '31_volume_5_aug_2.nrrd',
#  '21_volume_7_aug_2.nrrd',
#  '21_volume_6_aug_0.nrrd',
#  '25_volume_11_aug_1.nrrd',
#  '5_volume_3_aug_1.nrrd',
#  '7_volume_19_aug_2.nrrd',
#  '5_volume_4_aug_0.nrrd',
#  '6_volume_7_aug_2.nrrd',
#  '14_volume_5_aug_0.nrrd',
#  '9_volume_4_aug_2.nrrd',
#  '9_volume_8_aug_1.nrrd',
#  '87_volume_3_aug_1.nrrd',
#  '9_volume_2_aug_2.nrrd',
#  '25_volume_3_aug_1.nrrd',
#  '17_volume_1_aug_1.nrrd',
#  '48_volume_10_aug_2.nrrd',
#  '48_volume_4_aug_0.nrrd',
#  '25_volume_9_aug_0.nrrd',
#  '32_volume_8_aug_0.nrrd',
#  '61_volume_10_aug_2.nrrd',
#  '63_volume_2_aug_0.nrrd',
#  '48_volume_6_aug_2.nrrd',
#  '29_volume_7_aug_1.nrrd',
#  '88_volume_1_aug_0.nrrd',
#  '48_volume_3_aug_2.nrrd',
#  '64_volume_6_aug_2.nrrd',
#  '35_volume_5_aug_2.nrrd',
#  '5_volume_1_aug_0.nrrd',
#  '48_volume_2_aug_2.nrrd',
#  '63_volume_2_aug_2.nrrd',
#  '95_volume_6_aug_1.nrrd',
#  '7_volume_12_aug_0.nrrd',
#  '49_volume_5_aug_2.nrrd',
#  '13_volume_3_aug_1.nrrd',
#  '45_volume_6_aug_0.nrrd',
#  '75_volume_7_aug_0.nrrd',
#  '11_volume_1_aug_1.nrrd',
#  '46_volume_6_aug_1.nrrd',
#  '48_volume_1_aug_2.nrrd',
#  '9_volume_3_aug_0.nrrd',
#  '72_volume_4_aug_0.nrrd',
#  '97_volume_5_aug_2.nrrd',
#  '95_volume_10_aug_0.nrrd',
#  '11_volume_12_aug_1.nrrd',
#  '12_volume_5_aug_0.nrrd',
#  '48_volume_4_aug_1.nrrd',
#  '60_volume_7_aug_2.nrrd',
#  '7_volume_9_aug_1.nrrd',
#  '75_volume_4_aug_2.nrrd',
#  '5_volume_16_aug_1.nrrd',
#  '91_volume_8_aug_2.nrrd',
#  '52_volume_8_aug_2.nrrd',
#  '32_volume_6_aug_0.nrrd',
#  '33_volume_1_aug_1.nrrd',
#  '87_volume_10_aug_1.nrrd',
#  '7_volume_2_aug_2.nrrd',
#  '88_volume_3_aug_0.nrrd',
#  '31_volume_12_aug_1.nrrd',
#  '6_volume_12_aug_1.nrrd',
#  '92_volume_7_aug_1.nrrd',
#  '72_volume_2_aug_0.nrrd',
#  '49_volume_6_aug_1.nrrd',
#  '31_volume_7_aug_0.nrrd',
#  '12_volume_12_aug_2.nrrd',
#  '5_volume_7_aug_1.nrrd',
#  '69_volume_1_aug_0.nrrd',
#  '5_volume_17_aug_2.nrrd',
#  '6_volume_9_aug_0.nrrd',
#  '92_volume_9_aug_0.nrrd',
#  '5_volume_4_aug_1.nrrd',
#  '97_volume_9_aug_1.nrrd',
#  '69_volume_3_aug_0.nrrd',
#  '45_volume_8_aug_1.nrrd',
#  '79_volume_6_aug_1.nrrd',
#  '21_volume_11_aug_0.nrrd',
#  '2_volume_9_aug_2.nrrd',
#  '91_volume_11_aug_1.nrrd',
#  '35_volume_5_aug_0.nrrd',
#  '5_volume_4_aug_2.nrrd',
#  '63_volume_12_aug_1.nrrd',
#  '97_volume_6_aug_2.nrrd',
#  '97_volume_7_aug_0.nrrd',
#  '12_volume_11_aug_1.nrrd',
#  '95_volume_2_aug_0.nrrd',
#  '40_volume_2_aug_1.nrrd',
#  '7_volume_5_aug_0.nrrd',
#  '13_volume_1_aug_1.nrrd',
#  '11_volume_11_aug_1.nrrd',
#  '13_volume_6_aug_1.nrrd',
#  '79_volume_6_aug_2.nrrd',
#  '79_volume_7_aug_1.nrrd',
#  '88_volume_2_aug_1.nrrd',
#  '63_volume_4_aug_2.nrrd',
#  '14_volume_4_aug_1.nrrd',
#  '63_volume_4_aug_1.nrrd',
#  '25_volume_1_aug_1.nrrd',
#  '35_volume_4_aug_0.nrrd',
#  '40_volume_5_aug_1.nrrd',
#  '91_volume_5_aug_2.nrrd',
#  '5_volume_12_aug_1.nrrd',
#  '14_volume_1_aug_1.nrrd',
#  '49_volume_1_aug_1.nrrd',
#  '49_volume_2_aug_1.nrrd',
#  '72_volume_6_aug_1.nrrd',
#  '7_volume_3_aug_1.nrrd',
#  '60_volume_10_aug_2.nrrd',
#  '64_volume_2_aug_2.nrrd',
#  '25_volume_9_aug_1.nrrd',
#  '5_volume_10_aug_1.nrrd',
#  '14_volume_6_aug_2.nrrd',
#  '7_volume_1_aug_0.nrrd',
#  '60_volume_9_aug_0.nrrd',
#  '11_volume_7_aug_2.nrrd',
#  '12_volume_16_aug_2.nrrd',
#  '14_volume_2_aug_2.nrrd',
#  '96_volume_3_aug_2.nrrd',
#  '95_volume_8_aug_2.nrrd',
#  '14_volume_7_aug_1.nrrd',
#  '61_volume_7_aug_1.nrrd',
#  '69_volume_1_aug_1.nrrd',
#  '45_volume_2_aug_0.nrrd',
#  '61_volume_3_aug_0.nrrd',
#  '26_volume_4_aug_2.nrrd',
#  '49_volume_3_aug_2.nrrd',
#  '95_volume_2_aug_2.nrrd',
#  '29_volume_8_aug_0.nrrd',
#  '12_volume_10_aug_2.nrrd',
#  '95_volume_5_aug_1.nrrd',
#  '26_volume_9_aug_1.nrrd',
#  '95_volume_4_aug_2.nrrd',
#  '57_volume_5_aug_0.nrrd',
#  '33_volume_2_aug_1.nrrd',
#  '45_volume_6_aug_1.nrrd',
#  '11_volume_6_aug_0.nrrd',
#  '95_volume_12_aug_0.nrrd',
#  '26_volume_4_aug_1.nrrd',
#  '87_volume_5_aug_0.nrrd',
#  '57_volume_8_aug_2.nrrd',
#  '75_volume_9_aug_1.nrrd',
#  '7_volume_10_aug_1.nrrd',
#  '12_volume_7_aug_0.nrrd',
#  '25_volume_7_aug_0.nrrd',
#  '29_volume_10_aug_0.nrrd',
#  '33_volume_6_aug_1.nrrd',
#  '29_volume_1_aug_1.nrrd',
#  '5_volume_18_aug_0.nrrd',
#  '40_volume_1_aug_0.nrrd',
#  '69_volume_2_aug_0.nrrd',
#  '60_volume_6_aug_1.nrrd',
#  '7_volume_9_aug_0.nrrd',
#  '91_volume_12_aug_1.nrrd',
#  '52_volume_2_aug_2.nrrd',
#  '5_volume_21_aug_1.nrrd',
#  '83_volume_3_aug_0.nrrd',
#  '13_volume_5_aug_0.nrrd',
#  '6_volume_10_aug_0.nrrd',
#  '5_volume_8_aug_1.nrrd',
#  '87_volume_11_aug_2.nrrd',
#  '14_volume_9_aug_1.nrrd',
#  '31_volume_1_aug_2.nrrd',
#  '97_volume_10_aug_1.nrrd',
#  '12_volume_8_aug_1.nrrd',
#  '13_volume_2_aug_2.nrrd',
#  '49_volume_7_aug_1.nrrd',
#  '11_volume_8_aug_0.nrrd',
#  '12_volume_9_aug_2.nrrd',
#  '52_volume_6_aug_1.nrrd',
#  '26_volume_3_aug_1.nrrd',
#  '87_volume_7_aug_2.nrrd',
#  '21_volume_3_aug_1.nrrd',
#  '26_volume_14_aug_1.nrrd',
#  '5_volume_1_aug_2.nrrd',
#  '5_volume_18_aug_1.nrrd',
#  '63_volume_3_aug_0.nrrd',
#  '25_volume_11_aug_2.nrrd',
#  '11_volume_7_aug_0.nrrd',
#  '87_volume_4_aug_1.nrrd',
#  '52_volume_3_aug_2.nrrd',
#  '33_volume_5_aug_2.nrrd',
#  '96_volume_2_aug_0.nrrd',
#  '9_volume_5_aug_0.nrrd',
#  '75_volume_8_aug_0.nrrd',
#  '12_volume_17_aug_0.nrrd',
#  '35_volume_6_aug_0.nrrd',
#  '64_volume_9_aug_2.nrrd',
#  '29_volume_3_aug_1.nrrd',
#  '7_volume_16_aug_2.nrrd',
#  '2_volume_7_aug_0.nrrd',
#  '11_volume_3_aug_2.nrrd',
#  '57_volume_5_aug_1.nrrd',
#  '72_volume_2_aug_2.nrrd',
#  '92_volume_7_aug_0.nrrd',
#  '83_volume_4_aug_1.nrrd',
#  '84_volume_4_aug_2.nrrd',
#  '7_volume_9_aug_2.nrrd',
#  '95_volume_1_aug_0.nrrd',
#  '26_volume_2_aug_1.nrrd',
#  '13_volume_8_aug_0.nrrd',
#  '11_volume_5_aug_0.nrrd',
#  '63_volume_2_aug_1.nrrd',
#  '88_volume_4_aug_2.nrrd',
#  '14_volume_7_aug_0.nrrd',
#  '95_volume_1_aug_2.nrrd',
#  '60_volume_16_aug_2.nrrd',
#  '52_volume_1_aug_0.nrrd',
#  '6_volume_10_aug_1.nrrd',
#  '91_volume_1_aug_1.nrrd',
#  '13_volume_7_aug_2.nrrd',
#  '57_volume_7_aug_0.nrrd',
#  '83_volume_5_aug_0.nrrd',
#  '12_volume_2_aug_2.nrrd',
#  '35_volume_3_aug_1.nrrd',
#  '6_volume_9_aug_1.nrrd',
#  '64_volume_3_aug_0.nrrd',
#  '33_volume_5_aug_0.nrrd',
#  '91_volume_9_aug_2.nrrd',
#  '11_volume_14_aug_1.nrrd',
#  '69_volume_2_aug_2.nrrd',
#  '26_volume_4_aug_0.nrrd',
#  '40_volume_6_aug_2.nrrd',
#  '97_volume_5_aug_1.nrrd',
#  '11_volume_2_aug_1.nrrd',
#  '72_volume_7_aug_0.nrrd',
#  '26_volume_7_aug_1.nrrd',
#  '48_volume_5_aug_1.nrrd',
#  '87_volume_7_aug_0.nrrd',
#  '79_volume_6_aug_0.nrrd',
#  '87_volume_1_aug_0.nrrd',
#  '14_volume_8_aug_2.nrrd',
#  '63_volume_8_aug_0.nrrd',
#  '79_volume_7_aug_2.nrrd',
#  '48_volume_8_aug_0.nrrd',
#  '5_volume_12_aug_0.nrrd',
#  '21_volume_4_aug_0.nrrd',
#  '32_volume_2_aug_0.nrrd',
#  '60_volume_12_aug_1.nrrd',
#  '84_volume_3_aug_1.nrrd',
#  '21_volume_8_aug_2.nrrd',
#  '91_volume_7_aug_0.nrrd',
#  '46_volume_3_aug_2.nrrd',
#  '33_volume_5_aug_1.nrrd',
#  '31_volume_9_aug_0.nrrd',
#  '97_volume_1_aug_0.nrrd',
#  '75_volume_8_aug_2.nrrd',
#  '63_volume_6_aug_2.nrrd',
#  '31_volume_4_aug_0.nrrd',
#  '33_volume_4_aug_2.nrrd',
#  '88_volume_6_aug_0.nrrd',
#  '6_volume_11_aug_0.nrrd',
#  '95_volume_7_aug_0.nrrd',
#  '7_volume_21_aug_2.nrrd',
#  '26_volume_9_aug_0.nrrd',
#  '91_volume_8_aug_1.nrrd',
#  '25_volume_7_aug_2.nrrd',
#  '45_volume_7_aug_1.nrrd',
#  '11_volume_10_aug_1.nrrd',
#  '61_volume_1_aug_0.nrrd',
#  '75_volume_6_aug_2.nrrd',
#  '6_volume_2_aug_0.nrrd',
#  '64_volume_4_aug_2.nrrd',
#  '79_volume_5_aug_1.nrrd',
#  '5_volume_17_aug_1.nrrd',
#  '11_volume_3_aug_1.nrrd',
#  '75_volume_10_aug_1.nrrd',
#  '7_volume_8_aug_1.nrrd',
#  '95_volume_7_aug_2.nrrd',
#  '45_volume_3_aug_0.nrrd',
#  '25_volume_1_aug_2.nrrd',
#  '79_volume_2_aug_1.nrrd',
#  '9_volume_7_aug_0.nrrd',
#  '52_volume_7_aug_2.nrrd',
#  '95_volume_9_aug_2.nrrd',
#  '75_volume_1_aug_2.nrrd',
#  '14_volume_5_aug_2.nrrd',
#  '14_volume_10_aug_2.nrrd',
#  '63_volume_7_aug_0.nrrd',
#  '96_volume_1_aug_0.nrrd',
#  '31_volume_5_aug_1.nrrd',
#  '7_volume_11_aug_1.nrrd',
#  '92_volume_9_aug_1.nrrd',
#  '64_volume_7_aug_1.nrrd',
#  '60_volume_7_aug_0.nrrd',
#  '2_volume_5_aug_0.nrrd',
#  '49_volume_8_aug_1.nrrd',
#  '9_volume_4_aug_1.nrrd',
#  '13_volume_4_aug_2.nrrd',
#  '91_volume_9_aug_0.nrrd',
#  '46_volume_2_aug_1.nrrd',
#  '61_volume_7_aug_0.nrrd',
#  '40_volume_2_aug_0.nrrd',
#  '45_volume_7_aug_0.nrrd',
#  '97_volume_5_aug_0.nrrd',
#  '11_volume_1_aug_0.nrrd',
#  '33_volume_6_aug_2.nrrd',
#  '7_volume_18_aug_2.nrrd',
#  '64_volume_1_aug_1.nrrd',
#  '11_volume_15_aug_1.nrrd',
#  '61_volume_6_aug_2.nrrd',
#  '60_volume_2_aug_1.nrrd',
#  '12_volume_6_aug_1.nrrd',
#  '60_volume_11_aug_2.nrrd',
#  '6_volume_3_aug_1.nrrd',
#  '64_volume_5_aug_0.nrrd',
#  '92_volume_10_aug_1.nrrd',
#  '97_volume_3_aug_0.nrrd',
#  '60_volume_4_aug_1.nrrd',
#  '45_volume_5_aug_2.nrrd',
#  '6_volume_6_aug_1.nrrd',
#  '13_volume_5_aug_2.nrrd',
#  '5_volume_8_aug_2.nrrd',
#  '26_volume_11_aug_2.nrrd',
#  '7_volume_3_aug_0.nrrd',
#  '46_volume_1_aug_2.nrrd',
#  '11_volume_4_aug_1.nrrd',
#  '63_volume_5_aug_2.nrrd',
#  '84_volume_4_aug_0.nrrd',
#  '72_volume_2_aug_1.nrrd',
#  '6_volume_6_aug_2.nrrd',
#  '49_volume_3_aug_1.nrrd',
#  '2_volume_8_aug_0.nrrd',
#  '88_volume_1_aug_2.nrrd',
#  '21_volume_5_aug_1.nrrd',
#  '14_volume_11_aug_2.nrrd',
#  '12_volume_1_aug_2.nrrd',
#  '21_volume_6_aug_1.nrrd',
#  '29_volume_5_aug_1.nrrd',
#  '49_volume_6_aug_2.nrrd',
#  '40_volume_3_aug_0.nrrd',
#  '88_volume_5_aug_0.nrrd',
#  '29_volume_1_aug_0.nrrd',
#  '46_volume_5_aug_0.nrrd',
#  '46_volume_3_aug_1.nrrd',
#  '75_volume_2_aug_1.nrrd',
#  '21_volume_11_aug_2.nrrd',
#  '69_volume_4_aug_1.nrrd',
#  '6_volume_11_aug_1.nrrd',
#  '32_volume_10_aug_0.nrrd',
#  '26_volume_3_aug_2.nrrd',
#  '60_volume_14_aug_2.nrrd',
#  '7_volume_11_aug_2.nrrd',
#  '32_volume_2_aug_1.nrrd',
#  '6_volume_8_aug_2.nrrd',
#  '33_volume_4_aug_0.nrrd',
#  '40_volume_6_aug_1.nrrd',
#  '12_volume_9_aug_1.nrrd',
#  '60_volume_2_aug_0.nrrd',
#  '5_volume_9_aug_2.nrrd',
#  '49_volume_5_aug_0.nrrd',
#  '29_volume_4_aug_0.nrrd',
#  '5_volume_3_aug_2.nrrd',
#  '79_volume_4_aug_0.nrrd',
#  '32_volume_5_aug_0.nrrd',
#  '57_volume_5_aug_2.nrrd',
#  '83_volume_1_aug_0.nrrd',
#  '64_volume_7_aug_0.nrrd',
#  '9_volume_7_aug_2.nrrd',
#  '21_volume_2_aug_1.nrrd',
#  '48_volume_5_aug_0.nrrd',
#  '2_volume_5_aug_1.nrrd',
#  '26_volume_8_aug_2.nrrd',
#  '14_volume_12_aug_2.nrrd',
#  '60_volume_4_aug_2.nrrd',
#  '45_volume_4_aug_2.nrrd',
#  '29_volume_10_aug_2.nrrd',
#  '46_volume_1_aug_0.nrrd',
#  '32_volume_1_aug_2.nrrd',
#  '64_volume_2_aug_0.nrrd',
#  '97_volume_7_aug_2.nrrd',
#  '21_volume_2_aug_0.nrrd',
#  '11_volume_3_aug_0.nrrd',
#  '12_volume_4_aug_1.nrrd',
#  '7_volume_5_aug_2.nrrd',
#  '31_volume_7_aug_1.nrrd',
#  '14_volume_7_aug_2.nrrd',
#  '2_volume_4_aug_1.nrrd',
#  '14_volume_13_aug_2.nrrd',
#  '9_volume_1_aug_1.nrrd',
#  '63_volume_1_aug_0.nrrd',
#  '33_volume_3_aug_2.nrrd',
#  '6_volume_1_aug_1.nrrd',
#  '33_volume_6_aug_0.nrrd',
#  '2_volume_6_aug_0.nrrd',
#  '11_volume_2_aug_0.nrrd',
#  '2_volume_1_aug_2.nrrd',
#  '88_volume_2_aug_2.nrrd',
#  '12_volume_15_aug_0.nrrd',
#  '46_volume_4_aug_1.nrrd',
#  '29_volume_2_aug_2.nrrd',
#  '31_volume_9_aug_2.nrrd',
#  '35_volume_1_aug_1.nrrd',
#  '83_volume_5_aug_2.nrrd',
#  '35_volume_5_aug_1.nrrd',
#  '48_volume_4_aug_2.nrrd',
#  '60_volume_9_aug_2.nrrd',
#  '95_volume_2_aug_1.nrrd',
#  '87_volume_2_aug_2.nrrd',
#  '7_volume_4_aug_0.nrrd',
#  '29_volume_6_aug_2.nrrd',
#  '7_volume_10_aug_0.nrrd',
#  '14_volume_6_aug_1.nrrd',
#  '6_volume_5_aug_0.nrrd',
#  '97_volume_2_aug_1.nrrd',
#  '60_volume_14_aug_0.nrrd',
#  '79_volume_3_aug_1.nrrd',
#  '35_volume_6_aug_2.nrrd',
#  '6_volume_8_aug_1.nrrd',
#  '92_volume_4_aug_2.nrrd',
#  '11_volume_9_aug_0.nrrd',
#  '61_volume_10_aug_1.nrrd',
#  '92_volume_2_aug_1.nrrd',
#  '2_volume_8_aug_2.nrrd',
#  '92_volume_8_aug_0.nrrd',
#  '29_volume_2_aug_0.nrrd',
#  '31_volume_6_aug_0.nrrd',
#  '7_volume_7_aug_2.nrrd',
#  '96_volume_6_aug_1.nrrd',
#  '69_volume_4_aug_0.nrrd',
#  '46_volume_8_aug_1.nrrd',
#  '12_volume_3_aug_0.nrrd',
#  '12_volume_6_aug_0.nrrd',
#  '69_volume_3_aug_2.nrrd',
#  '52_volume_6_aug_2.nrrd',
#  '87_volume_5_aug_2.nrrd',
#  ...]
