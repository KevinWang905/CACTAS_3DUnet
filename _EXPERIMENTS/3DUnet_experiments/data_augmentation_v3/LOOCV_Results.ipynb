# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
ious = []
for file in os.listdir('./test_data/reform/metrics'):
    df = pd.read_csv(r'./test_data/reform/metrics/'+file, header=None) 
    best_iou = np.array(df.sort_values(by=0, ascending=False).iloc[0])
    ious.append(best_iou)

# %%
ious = np.array(ious)
ious
# Out:
# array([[0.59259259, 0.74418605, 0.68292683, 0.81751825],
#        [0.51470588, 0.67961165, 0.59322034, 0.79545455],
#        [0.6779661 , 0.80808081, 0.76433121, 0.85714286],
#        [0.65882353, 0.79432624, 0.67878788, 0.95726496],
#        [0.61861862, 0.76437848, 0.81262327, 0.72154116],
#        [0.76363636, 0.86597938, 0.93333333, 0.80769231],
#        [0.63851351, 0.77938144, 0.73255814, 0.83259912],
#        [0.80952381, 0.89473684, 0.91891892, 0.87179487],
#        [0.74935799, 0.85672343, 0.85874044, 0.85471588],
#        [0.72610556, 0.84132231, 0.8634436 , 0.8203062 ],
#        [0.74788136, 0.85575758, 0.86519608, 0.84652278],
#        [0.72033898, 0.83743842, 0.84158416, 0.83333333],
#        [0.66666667, 0.8       , 0.90909091, 0.71428571],
#        [0.76374745, 0.86605081, 0.88028169, 0.85227273],
#        [0.5607064 , 0.718529  , 0.6529563 , 0.79874214],
#        [0.55700935, 0.71548619, 0.63539446, 0.81868132],
#        [0.73298429, 0.84592145, 0.84337349, 0.84848485],
#        [0.70915033, 0.82982792, 0.81578947, 0.84435798],
#        [0.72289157, 0.83916084, 0.78817734, 0.89719626],
#        [0.58490566, 0.73809524, 0.76229508, 0.71538462],
#        [0.51339286, 0.67846608, 0.54245283, 0.90551181],
#        [0.69863014, 0.82258065, 0.75      , 0.91071429],
#        [0.12356792, 0.2199563 , 0.28066914, 0.18083832],
#        [0.73333333, 0.84615385, 0.95652174, 0.75862069],
#        [0.68338109, 0.81191489, 0.92084942, 0.7260274 ],
#        [0.73127753, 0.84478372, 0.81773399, 0.87368421],
#        [0.62616822, 0.77011494, 0.69072165, 0.87012987],
#        [0.52941176, 0.69230769, 0.6       , 0.81818182],
#        [0.20915033, 0.34594595, 0.22857143, 0.71111111],
#        [0.63920455, 0.77989601, 0.72115385, 0.8490566 ],
#        [0.59090909, 0.74285714, 0.72222222, 0.76470588],
#        [0.65083799, 0.78849408, 0.72248062, 0.86778399],
#        [0.61118509, 0.75867769, 0.86767486, 0.67400881],
#        [0.47993019, 0.64858491, 0.57692308, 0.74057451],
#        [0.67610748, 0.8067591 , 0.77518734, 0.84101174],
#        [0.47976879, 0.6484375 , 0.5561139 , 0.77751756],
#        [0.76315789, 0.86567164, 0.82857143, 0.90625   ],
#        [0.5       , 0.66666667, 0.6       , 0.75      ],
#        [0.71428571, 0.83333333, 0.78947368, 0.88235294],
#        [0.46582915, 0.6355845 , 0.70015106, 0.5819209 ],
#        [0.54395916, 0.70462895, 0.76444799, 0.65349233],
#        [0.68950517, 0.81622144, 0.80712922, 0.82552083]])

# %%
print(np.mean(ious[:,0]))
print(np.mean(ious[:,1]))
print(np.mean(ious[:,2]))
print(np.mean(ious[:,3]))
# Out:
# 0.6230742726954256
# 0.7572150259448812
# 0.7393350567368907
# 0.7946263686559865

# %%
fig, axes = plt.subplots(1, 4, figsize=(20,5))
titles = ['IoU', 'F1', 'Sensitivity', 'Precision']
ymaxes = [11, 13, 7, 14]

for i in range(0, 4):
    sns.histplot(ax=axes[i], data=ious[:,i], bins = 15)
    axes[i].plot([np.mean(ious[:,i]), np.mean(ious[:,i])], [ymaxes[i], 0], linewidth=2, color='r')
    axes[i].text(np.mean(ious[:,i])-0.25, ymaxes[i], 'Mean: '+str(np.round(np.mean(ious[:,i]),2)))
    axes[i].set_title(titles[i])
    axes[i].set_xlim(0, 1)
