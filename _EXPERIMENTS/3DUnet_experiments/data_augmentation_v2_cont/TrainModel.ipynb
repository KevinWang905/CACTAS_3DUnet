# %%
# %pip install scikit-learn
# Out:
# /bin/bash: /home/kevin.wang/miniconda3/envs/tf-gpu-py310/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: scikit-learn in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import nrrd
import os
from sklearn.model_selection import train_test_split
print("------------------------------------------------------------------------------------------------")
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print("------------------------------------------------------------------------------------------------")
# Out:
# 2024-06-23 17:21:36.836525: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-23 17:21:37.428511: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ------------------------------------------------------------------------------------------------
# 2.16.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ------------------------------------------------------------------------------------------------

# %%
def encoder_block(inputs, output_channels, lastlayer=False):
    """
    Two 3x3x3 convolutions with batch normalization and ReLU activation
    2x2x2 max pool
    """

    # 3x3x3 convolutions with ReLU activation
    x = tf.keras.layers.Conv3D(int(output_channels/2), kernel_size=3, strides=1, padding='same')(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)
    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    # 2x2x2 max pool

    if not lastlayer:
        x_maxPool = tf.keras.layers.MaxPool3D(pool_size=2, strides=2, padding = 'same')(x)
    else:
        x_maxPool = x

    return x, x_maxPool

def decoder_block(inputs, skip_features, output_channels):

    # Upsampling with 2x2x2 filter
    x = tf.keras.layers.Conv3DTranspose(output_channels*2, kernel_size=2, strides=2, padding = 'same')(inputs)

# Concatenate the skip features
    x = tf.keras.layers.Concatenate()([x, skip_features])

    # 2 convolutions with 3x3 filter, batch normalization, ReLU activation
    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    x = tf.keras.layers.Conv3D(output_channels, kernel_size=3, strides=1, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.ReLU()(x)

    return x

def unet_3D():
    inputs = tf.keras.Input(shape=(64, 64, 64, 1,))

    e1_skip, e1_maxpool = encoder_block(inputs, 64)
    e2_skip, e2_maxpool = encoder_block(e1_maxpool, 128)
    e3_skip, e3_maxpool = encoder_block(e2_maxpool, 256)
    _, e4 = encoder_block(e3_maxpool, 512, True)

    decoder1 = decoder_block(e4, e3_skip, 256)
    decoder2 = decoder_block(decoder1, e2_skip, 128)
    decoder3 = decoder_block(decoder2, e1_skip, 64)

    outputs = tf.keras.layers.Conv3D(1, 1, strides = 1)(decoder3)
    outputs = tf.keras.layers.Activation('sigmoid')(outputs)

    model = tf.keras.models.Model(inputs = inputs,  outputs = outputs,  name = 'Unet3D')

    return model

# %%
def iou(y_true, y_pred, smooth=0.000000001):
    # yt = K.argmax(y_true, axis=2)
    # yp = K.argmax(y_pred, axis=2)
    # print(y_pred)
    #yp = y_pred[0]
    # yp[yp>=0.5]=1
    # yp[yp<0.5]=0
    yp = y_pred
    yp = tf.where(yp >= 0.5, tf.ones_like(yp), yp)
    yp = tf.where(yp < 0.5, tf.zeros_like(yp), yp)
    yp = K.cast(yp, np.float32)

    yt = K.cast(y_true, np.float32)

    # print(yt.shape)
    # print(yp.shape)
    
    intersection = K.sum(yt * yp)
    union = K.sum(yt) + K.sum(yp)
    # intersection = K.sum(yt * yp, axis=1)
    # union = K.sum(yt, axis=1) + K.sum(yp, axis=1)
    return (intersection + smooth) / (union-intersection+smooth)

# %%
model = unet_3D()
# model.summary()

print("compiling model")
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='dice', metrics=[iou])#, metrics=[iou])
# Out:
# compiling model
# 2024-06-23 17:21:38.503068: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9705 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:65:00.0, compute capability: 8.9

# %%
model.load_weights("./checkpoints/cp-0176.weights.h5")
# Out:
# /home/kevin.wang/miniconda3/envs/cactas/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 130 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return 0.0001
    elif 10 <= epoch < 20:
        return 0.00005
    elif 20 <= epoch < 30:
        return 0.00001
    elif 30 <= epoch < 50:
        return 0.000005
    elif 50 <= epoch:
        return 0.000001

# %%
trainlist = os.listdir("./gt")

# %%
import ast
print("loading inputs")

number_inputs = len(trainlist)

X, _ =  nrrd.read("inputs/" + trainlist[0])
X = np.array([X]).astype(np.float32)
X = np.expand_dims(X, -1)
for i in range(1, number_inputs):

    try:
        volume, _ =  nrrd.read("inputs/" + trainlist[i])
        volume = np.array([volume])
        volume = np.expand_dims(volume, -1)
        X = np.concatenate((X, volume), axis=0)
    except:
        print("skipping " + trainlist[i])

print("loading ground truths")

valid_samples = [trainlist[0]]

y, _ =  nrrd.read("gt/" + trainlist[0])
y = np.array([y])
y = np.expand_dims(y, axis=-1)

for i in range(1, number_inputs):
    try:
        volume, _ =  nrrd.read("gt/" + trainlist[i])
        volume = np.array([volume])
        volume = np.expand_dims(volume, axis=-1)
        y = np.concatenate((y, volume), axis=0)
        valid_samples.append(trainlist[i])
    except:
        print("skipping " + trainlist[i])

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=1)
# Out:
# loading inputs
# skipping 63_volume_13_aug_1.nrrd
# skipping 5_volume_22_aug_1.nrrd
# skipping 31_volume_14_aug_1.nrrd
# skipping 31_volume_10_aug_0.nrrd
# skipping 31_volume_10_aug_2.nrrd
# skipping 5_volume_19_aug_1.nrrd
# skipping 91_volume_10_aug_0.nrrd
# skipping 84_volume_7_aug_0.nrrd
# skipping 31_volume_12_aug_1.nrrd
# skipping 63_volume_12_aug_1.nrrd
# skipping 5_volume_21_aug_1.nrrd
# skipping 63_volume_8_aug_0.nrrd
# skipping 63_volume_6_aug_2.nrrd
# skipping 91_volume_9_aug_0.nrrd
# skipping 31_volume_9_aug_2.nrrd
# skipping 63_volume_11_aug_1.nrrd
# skipping 5_volume_20_aug_1.nrrd
# skipping 31_volume_13_aug_1.nrrd
# loading ground truths
# skipping 63_volume_13_aug_1.nrrd
# skipping 5_volume_22_aug_1.nrrd
# skipping 31_volume_14_aug_1.nrrd
# skipping 31_volume_10_aug_0.nrrd
# skipping 31_volume_10_aug_2.nrrd
# skipping 5_volume_19_aug_1.nrrd
# skipping 91_volume_10_aug_0.nrrd
# skipping 84_volume_7_aug_0.nrrd
# skipping 31_volume_12_aug_1.nrrd
# skipping 63_volume_12_aug_1.nrrd
# skipping 5_volume_21_aug_1.nrrd
# skipping 63_volume_8_aug_0.nrrd
# skipping 63_volume_6_aug_2.nrrd
# skipping 91_volume_9_aug_0.nrrd
# skipping 31_volume_9_aug_2.nrrd
# skipping 63_volume_11_aug_1.nrrd
# skipping 5_volume_20_aug_1.nrrd
# skipping 31_volume_13_aug_1.nrrd

# %%
# Checkpoint Saving
checkpoint_path = "./checkpoints/cont-cp-{epoch:04d}.weights.h5"
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, verbose=1,
                                                 save_weights_only=True, save_freq='epoch') #save_freq=1850)

# Learning Rate callback
import keras
lr_callback = keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

# %%
print("---------------- fitting model ---------------------")
model.fit(x=X_train, y=y_train, validation_data=(X_val, y_val), batch_size=2, epochs=60, callbacks = [cp_callback, lr_callback])
# Out:
# ---------------- fitting model ---------------------
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719178106.532832 1965926 service.cc:145] XLA service 0x7aca78033dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1719178106.532919 1965926 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-06-23 17:28:26.717732: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-23 17:28:27.442530: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
#   1/521 ━━━━━━━━━━━━━━━━━━━━ 3:39:25 25s/step - iou: 0.8505 - loss: 0.0809
# I0000 00:00:1719178125.864626 1965926 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - iou: 0.6414 - loss: 0.5415
# Epoch 1: saving model to ./checkpoints/cont-cp-0001.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 119s 180ms/step - iou: 0.6414 - loss: 0.5415 - val_iou: 0.5222 - val_loss: 0.6378 - learning_rate: 1.0000e-04
# Epoch 2/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.6619 - loss: 0.5126
# Epoch 2: saving model to ./checkpoints/cont-cp-0002.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.6619 - loss: 0.5126 - val_iou: 0.5319 - val_loss: 0.6324 - learning_rate: 1.0000e-04
# Epoch 3/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.6617 - loss: 0.4977
# Epoch 3: saving model to ./checkpoints/cont-cp-0003.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.6617 - loss: 0.4977 - val_iou: 0.5493 - val_loss: 0.6316 - learning_rate: 1.0000e-04
# Epoch 4/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.6857 - loss: 0.5324
# Epoch 4: saving model to ./checkpoints/cont-cp-0004.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.6856 - loss: 0.5324 - val_iou: 0.5288 - val_loss: 0.6361 - learning_rate: 1.0000e-04
# Epoch 5/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.6776 - loss: 0.5470
# Epoch 5: saving model to ./checkpoints/cont-cp-0005.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.6776 - loss: 0.5469 - val_iou: 0.5512 - val_loss: 0.6332 - learning_rate: 1.0000e-04
# Epoch 6/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.6809 - loss: 0.5239
# Epoch 6: saving model to ./checkpoints/cont-cp-0006.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.6809 - loss: 0.5239 - val_iou: 0.5590 - val_loss: 0.6447 - learning_rate: 1.0000e-04
# Epoch 7/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7211 - loss: 0.5107
# Epoch 7: saving model to ./checkpoints/cont-cp-0007.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7211 - loss: 0.5107 - val_iou: 0.5645 - val_loss: 0.6393 - learning_rate: 1.0000e-04
# Epoch 8/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7213 - loss: 0.5280
# Epoch 8: saving model to ./checkpoints/cont-cp-0008.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7213 - loss: 0.5280 - val_iou: 0.5642 - val_loss: 0.6397 - learning_rate: 1.0000e-04
# Epoch 9/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7048 - loss: 0.5144
# Epoch 9: saving model to ./checkpoints/cont-cp-0009.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7048 - loss: 0.5144 - val_iou: 0.5481 - val_loss: 0.6360 - learning_rate: 1.0000e-04
# Epoch 10/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.6939 - loss: 0.4763
# Epoch 10: saving model to ./checkpoints/cont-cp-0010.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.6939 - loss: 0.4764 - val_iou: 0.5462 - val_loss: 0.6391 - learning_rate: 1.0000e-04
# Epoch 11/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.6742 - loss: 0.5113
# Epoch 11: saving model to ./checkpoints/cont-cp-0011.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.6742 - loss: 0.5113 - val_iou: 0.5469 - val_loss: 0.6400 - learning_rate: 5.0000e-05
# Epoch 12/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7196 - loss: 0.4996
# Epoch 12: saving model to ./checkpoints/cont-cp-0012.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7196 - loss: 0.4996 - val_iou: 0.5481 - val_loss: 0.6375 - learning_rate: 5.0000e-05
# Epoch 13/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7082 - loss: 0.5289
# Epoch 13: saving model to ./checkpoints/cont-cp-0013.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7082 - loss: 0.5288 - val_iou: 0.5676 - val_loss: 0.6361 - learning_rate: 5.0000e-05
# Epoch 14/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7028 - loss: 0.4653
# Epoch 14: saving model to ./checkpoints/cont-cp-0014.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7028 - loss: 0.4654 - val_iou: 0.5440 - val_loss: 0.6428 - learning_rate: 5.0000e-05
# Epoch 15/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7386 - loss: 0.5128
# Epoch 15: saving model to ./checkpoints/cont-cp-0015.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7386 - loss: 0.5128 - val_iou: 0.5426 - val_loss: 0.6477 - learning_rate: 5.0000e-05
# Epoch 16/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7362 - loss: 0.5016
# Epoch 16: saving model to ./checkpoints/cont-cp-0016.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7361 - loss: 0.5016 - val_iou: 0.5337 - val_loss: 0.6362 - learning_rate: 5.0000e-05
# Epoch 17/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7261 - loss: 0.4991
# Epoch 17: saving model to ./checkpoints/cont-cp-0017.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7261 - loss: 0.4991 - val_iou: 0.5524 - val_loss: 0.6322 - learning_rate: 5.0000e-05
# Epoch 18/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7273 - loss: 0.4901
# Epoch 18: saving model to ./checkpoints/cont-cp-0018.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7273 - loss: 0.4902 - val_iou: 0.5685 - val_loss: 0.6358 - learning_rate: 5.0000e-05
# Epoch 19/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7206 - loss: 0.5419
# Epoch 19: saving model to ./checkpoints/cont-cp-0019.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7206 - loss: 0.5418 - val_iou: 0.5632 - val_loss: 0.6436 - learning_rate: 5.0000e-05
# Epoch 20/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7423 - loss: 0.5018
# Epoch 20: saving model to ./checkpoints/cont-cp-0020.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7423 - loss: 0.5018 - val_iou: 0.5693 - val_loss: 0.6354 - learning_rate: 5.0000e-05
# Epoch 21/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7544 - loss: 0.4997
# Epoch 21: saving model to ./checkpoints/cont-cp-0021.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7544 - loss: 0.4997 - val_iou: 0.5646 - val_loss: 0.6403 - learning_rate: 1.0000e-05
# Epoch 22/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7417 - loss: 0.5005
# Epoch 22: saving model to ./checkpoints/cont-cp-0022.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7416 - loss: 0.5005 - val_iou: 0.5676 - val_loss: 0.6365 - learning_rate: 1.0000e-05
# Epoch 23/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7271 - loss: 0.5178
# Epoch 23: saving model to ./checkpoints/cont-cp-0023.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7271 - loss: 0.5178 - val_iou: 0.5474 - val_loss: 0.6396 - learning_rate: 1.0000e-05
# Epoch 24/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7512 - loss: 0.4966
# Epoch 24: saving model to ./checkpoints/cont-cp-0024.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7512 - loss: 0.4967 - val_iou: 0.5679 - val_loss: 0.6370 - learning_rate: 1.0000e-05
# Epoch 25/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7401 - loss: 0.4832
# Epoch 25: saving model to ./checkpoints/cont-cp-0025.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 154ms/step - iou: 0.7400 - loss: 0.4832 - val_iou: 0.5340 - val_loss: 0.6344 - learning_rate: 1.0000e-05
# Epoch 26/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7428 - loss: 0.4928
# Epoch 26: saving model to ./checkpoints/cont-cp-0026.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7428 - loss: 0.4928 - val_iou: 0.5677 - val_loss: 0.6355 - learning_rate: 1.0000e-05
# Epoch 27/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7048 - loss: 0.5249
# Epoch 27: saving model to ./checkpoints/cont-cp-0027.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7048 - loss: 0.5249 - val_iou: 0.5511 - val_loss: 0.6349 - learning_rate: 1.0000e-05
# Epoch 28/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7306 - loss: 0.4746
# Epoch 28: saving model to ./checkpoints/cont-cp-0028.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7306 - loss: 0.4747 - val_iou: 0.5528 - val_loss: 0.6331 - learning_rate: 1.0000e-05
# Epoch 29/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7341 - loss: 0.5074
# Epoch 29: saving model to ./checkpoints/cont-cp-0029.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7341 - loss: 0.5074 - val_iou: 0.5521 - val_loss: 0.6356 - learning_rate: 1.0000e-05
# Epoch 30/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7258 - loss: 0.4977
# Epoch 30: saving model to ./checkpoints/cont-cp-0030.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7258 - loss: 0.4977 - val_iou: 0.5513 - val_loss: 0.6349 - learning_rate: 1.0000e-05
# Epoch 31/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7320 - loss: 0.5137
# Epoch 31: saving model to ./checkpoints/cont-cp-0031.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7320 - loss: 0.5137 - val_iou: 0.5486 - val_loss: 0.6367 - learning_rate: 5.0000e-06
# Epoch 32/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7388 - loss: 0.5010
# Epoch 32: saving model to ./checkpoints/cont-cp-0032.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7388 - loss: 0.5010 - val_iou: 0.5672 - val_loss: 0.6361 - learning_rate: 5.0000e-06
# Epoch 33/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7174 - loss: 0.4853
# Epoch 33: saving model to ./checkpoints/cont-cp-0033.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7174 - loss: 0.4854 - val_iou: 0.5672 - val_loss: 0.6360 - learning_rate: 5.0000e-06
# Epoch 34/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7563 - loss: 0.5181
# Epoch 34: saving model to ./checkpoints/cont-cp-0034.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7563 - loss: 0.5180 - val_iou: 0.5514 - val_loss: 0.6347 - learning_rate: 5.0000e-06
# Epoch 35/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7448 - loss: 0.4782
# Epoch 35: saving model to ./checkpoints/cont-cp-0035.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7448 - loss: 0.4783 - val_iou: 0.5689 - val_loss: 0.6348 - learning_rate: 5.0000e-06
# Epoch 36/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7067 - loss: 0.4785
# Epoch 36: saving model to ./checkpoints/cont-cp-0036.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7067 - loss: 0.4785 - val_iou: 0.5684 - val_loss: 0.6349 - learning_rate: 5.0000e-06
# Epoch 37/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7146 - loss: 0.4645
# Epoch 37: saving model to ./checkpoints/cont-cp-0037.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7147 - loss: 0.4646 - val_iou: 0.5689 - val_loss: 0.6330 - learning_rate: 5.0000e-06
# Epoch 38/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7202 - loss: 0.5278
# Epoch 38: saving model to ./checkpoints/cont-cp-0038.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7202 - loss: 0.5277 - val_iou: 0.5685 - val_loss: 0.6352 - learning_rate: 5.0000e-06
# Epoch 39/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7225 - loss: 0.5332
# Epoch 39: saving model to ./checkpoints/cont-cp-0039.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7225 - loss: 0.5332 - val_iou: 0.5679 - val_loss: 0.6359 - learning_rate: 5.0000e-06
# Epoch 40/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7320 - loss: 0.4988
# Epoch 40: saving model to ./checkpoints/cont-cp-0040.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7320 - loss: 0.4988 - val_iou: 0.5556 - val_loss: 0.6258 - learning_rate: 5.0000e-06
# Epoch 41/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7205 - loss: 0.5464
# Epoch 41: saving model to ./checkpoints/cont-cp-0041.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7205 - loss: 0.5464 - val_iou: 0.5511 - val_loss: 0.6337 - learning_rate: 5.0000e-06
# Epoch 42/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7387 - loss: 0.5116
# Epoch 42: saving model to ./checkpoints/cont-cp-0042.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7387 - loss: 0.5116 - val_iou: 0.5660 - val_loss: 0.6376 - learning_rate: 5.0000e-06
# Epoch 43/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7054 - loss: 0.4902
# Epoch 43: saving model to ./checkpoints/cont-cp-0043.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7054 - loss: 0.4902 - val_iou: 0.5509 - val_loss: 0.6345 - learning_rate: 5.0000e-06
# Epoch 44/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7094 - loss: 0.4906
# Epoch 44: saving model to ./checkpoints/cont-cp-0044.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7094 - loss: 0.4907 - val_iou: 0.5524 - val_loss: 0.6333 - learning_rate: 5.0000e-06
# Epoch 45/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7151 - loss: 0.4871
# Epoch 45: saving model to ./checkpoints/cont-cp-0045.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7151 - loss: 0.4871 - val_iou: 0.5687 - val_loss: 0.6348 - learning_rate: 5.0000e-06
# Epoch 46/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7056 - loss: 0.5259
# Epoch 46: saving model to ./checkpoints/cont-cp-0046.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7057 - loss: 0.5259 - val_iou: 0.5688 - val_loss: 0.6338 - learning_rate: 5.0000e-06
# Epoch 47/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7195 - loss: 0.5133
# Epoch 47: saving model to ./checkpoints/cont-cp-0047.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7195 - loss: 0.5134 - val_iou: 0.5536 - val_loss: 0.6330 - learning_rate: 5.0000e-06
# Epoch 48/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7093 - loss: 0.4958
# Epoch 48: saving model to ./checkpoints/cont-cp-0048.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7093 - loss: 0.4958 - val_iou: 0.5698 - val_loss: 0.6346 - learning_rate: 5.0000e-06
# Epoch 49/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7416 - loss: 0.4793
# Epoch 49: saving model to ./checkpoints/cont-cp-0049.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7416 - loss: 0.4794 - val_iou: 0.5678 - val_loss: 0.6357 - learning_rate: 5.0000e-06
# Epoch 50/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7319 - loss: 0.4821
# Epoch 50: saving model to ./checkpoints/cont-cp-0050.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7319 - loss: 0.4822 - val_iou: 0.5687 - val_loss: 0.6347 - learning_rate: 5.0000e-06
# Epoch 51/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7204 - loss: 0.5497
# Epoch 51: saving model to ./checkpoints/cont-cp-0051.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7204 - loss: 0.5496 - val_iou: 0.5654 - val_loss: 0.6377 - learning_rate: 1.0000e-06
# Epoch 52/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7301 - loss: 0.5202
# Epoch 52: saving model to ./checkpoints/cont-cp-0052.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7301 - loss: 0.5201 - val_iou: 0.5539 - val_loss: 0.6333 - learning_rate: 1.0000e-06
# Epoch 53/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - iou: 0.7103 - loss: 0.5096
# Epoch 53: saving model to ./checkpoints/cont-cp-0053.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7103 - loss: 0.5096 - val_iou: 0.5520 - val_loss: 0.6318 - learning_rate: 1.0000e-06
# Epoch 54/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7058 - loss: 0.5290
# Epoch 54: saving model to ./checkpoints/cont-cp-0054.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7058 - loss: 0.5290 - val_iou: 0.5700 - val_loss: 0.6340 - learning_rate: 1.0000e-06
# Epoch 55/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7486 - loss: 0.5231
# Epoch 55: saving model to ./checkpoints/cont-cp-0055.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7486 - loss: 0.5231 - val_iou: 0.5506 - val_loss: 0.6349 - learning_rate: 1.0000e-06
# Epoch 56/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7443 - loss: 0.4923
# Epoch 56: saving model to ./checkpoints/cont-cp-0056.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7443 - loss: 0.4923 - val_iou: 0.5505 - val_loss: 0.6342 - learning_rate: 1.0000e-06
# Epoch 57/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7433 - loss: 0.4951
# Epoch 57: saving model to ./checkpoints/cont-cp-0057.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7433 - loss: 0.4951 - val_iou: 0.5534 - val_loss: 0.6335 - learning_rate: 1.0000e-06
# Epoch 58/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7424 - loss: 0.4999
# Epoch 58: saving model to ./checkpoints/cont-cp-0058.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 81s 155ms/step - iou: 0.7423 - loss: 0.4999 - val_iou: 0.5682 - val_loss: 0.6357 - learning_rate: 1.0000e-06
# Epoch 59/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7095 - loss: 0.5638
# Epoch 59: saving model to ./checkpoints/cont-cp-0059.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7095 - loss: 0.5637 - val_iou: 0.5499 - val_loss: 0.6366 - learning_rate: 1.0000e-06
# Epoch 60/60
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - iou: 0.7166 - loss: 0.5167
# Epoch 60: saving model to ./checkpoints/cont-cp-0060.weights.h5
# 521/521 ━━━━━━━━━━━━━━━━━━━━ 80s 154ms/step - iou: 0.7166 - loss: 0.5166 - val_iou: 0.5523 - val_loss: 0.6332 - learning_rate: 1.0000e-06
